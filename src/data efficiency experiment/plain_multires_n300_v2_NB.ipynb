# %% [markdown]
# # Data-efficiency v2 â€” Plain Multires, \(n_{\mathrm{train}}=300\)
#
# Follows **`PROTOCOL_v2.txt` / `PROTOCOL_v2.md`** (plain network only, \(\lambda=0\)).
#
# | Item | Value |
# |------|-------|
# | Protocol | **v2** |
# | Data | Spectrally filtered C1 |
# | Model | Multires, \(\lambda=0\) |
# | \(n_{\mathrm{train}}\) | **300** |
# | \(n_{\mathrm{val}}\) / \(n_{\mathrm{test}}\) | 200 / 512 (shared seeds) |
# | Batch \(B\) | **64** |
# | LR | **\(10^{-3}\)** fixed (no LR tuning) |
# | Train SNR | U[0, 30] dB |
# | Val SNR | discrete **\{âˆ’10, 0, 30\}** dB |
# | Early stop | `patience_steps=800`, `max_steps=6400` (\(n\le 3000\) band; operator-adjustable) |
# | Snapshots | every 2 epochs; fixed val sample @ SNR=10 dB |
#
# Artifacts: `checkpoints/v2/n300_plain/` under this folder.
#
# Run order: setup â†’ Helpers â†’ train â†’ curves â†’ snapshots â†’ SNR sweep â†’ test example â†’ summary.

# %%
import os
os.environ.setdefault("KMP_DUPLICATE_LIB_OK", "TRUE")
try:
    from IPython import get_ipython
    _ip = get_ipython()
    if _ip is not None:
        _ip.run_line_magic("matplotlib", "inline")
except Exception:
    pass

from pathlib import Path
import json
import math
import sys
import time

import matplotlib.pyplot as plt
import numpy as np
import torch

HERE = Path.cwd()
if (HERE / "setup_src_path.py").exists():
    sys.path.insert(0, str(HERE))
    import setup_src_path  # noqa: F401
    EXP = HERE
elif (HERE / "data efficiency experiment" / "setup_src_path.py").exists():
    EXP = HERE / "data efficiency experiment"
    sys.path.insert(0, str(EXP))
    import setup_src_path  # noqa: F401
else:
    raise RuntimeError("Run from src/ or from data efficiency experiment/")

import data_c_amb_loss_diagnostics as diag
from data_generation import filtered_c1_pulse_config
from dataset_utils import build_filtered_c1_frog_dataloaders
from evaluate_cnn import load_cnn_sweep
from frog_reconstruction_model import extract_pulse_prediction
from pulse_metrics import (
    best_l1_ambiguity,
    best_l1_ambiguity_field,
    best_similarity_error_ambiguity,
    prepare_frog_trace_for_plot,
    unpack_packed_field,
    unwrap_phases_for_overlay,
)

DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
OUT = EXP / "checkpoints" / "v2" / "n300_plain"
OUT.mkdir(parents=True, exist_ok=True)

PROTOCOL = "v2"
N_TRAIN = 300
N_VAL = 200
N_TEST = 512
BATCH_SIZE = 64
SEED = 0  # val=seed+1, test=seed+2
LR = 1e-3
EARLY_STOP_MODE = "steps"
TRAIN_SNR = (0.0, 30.0)
VAL_SNR_RANGE = (-10.0, 30.0)  # unused when VAL_SNR_VALUES is set
VAL_SNR_VALUES = [-10.0, 0.0, 30.0]  # PROTOCOL v2 discrete val SNR
SNR_SWEEP_DB = np.arange(-10.0, 31.0, 5.0)
SNAPSHOT_EVERY = 2
SNAPSHOT_SNR_DB = 10.0
SNAPSHOT_VAL_INDEX = 0
SNAPSHOT_NOISE_SEED = 12345

STEPS_PER_EPOCH = math.ceil(N_TRAIN / BATCH_SIZE)  # K
# PROTOCOL v2: n_train <= 3000 band (adjustable by operator decision)
MAX_STEPS = 6400
PATIENCE_STEPS = 800
MAX_EPOCHS = max(1, math.ceil(MAX_STEPS / STEPS_PER_EPOCH))

FORCE_RETRAIN = False
FORCE_TEST_SWEEP = False

print("device:", DEVICE)
print("protocol:", PROTOCOL)
print("EXP:", EXP.resolve())
print("OUT:", OUT.resolve())
print("pulse cfg:", filtered_c1_pulse_config(n=64))
print(
    f"n_train={N_TRAIN}  B={BATCH_SIZE}  K={STEPS_PER_EPOCH}  "
    f"LR={LR:g}  max_steps={MAX_STEPS}  patience_steps={PATIENCE_STEPS}  "
    f"max_epochs={MAX_EPOCHS}"
)
print("train SNR: U[0,30]  |  val SNR values:", VAL_SNR_VALUES)
print(f"early_stop: {EARLY_STOP_MODE}")
print(f"FORCE_RETRAIN={FORCE_RETRAIN}  FORCE_TEST_SWEEP={FORCE_TEST_SWEEP}")
# Out:
# device: cuda
# protocol: v2
# EXP: D:\Haim\Haim 3rd paper\Ultra-Fast project\src\data efficiency experiment
# OUT: D:\Haim\Haim 3rd paper\Ultra-Fast project\src\data efficiency experiment\checkpoints\v2\n300_plain
# pulse cfg: FilteredC1PulseConfig(n=64, t_total_fs=70.0, n_spikes=500, central_energy_ev=10000.0, coherence_time_fs=1.0, t_center_std_fs=5.73, delta_energy_ev_range=0.00065, fwhm_ev=0.45, amplitude_min=0.75, amplitude_max=1.0, use_delta_omega=True)
# n_train=300  B=64  K=5  LR=0.001  max_steps=6400  patience_steps=800  max_epochs=1280
# train SNR: U[0,30]  |  val SNR values: [-10.0, 0.0, 30.0]
# early_stop: steps
# FORCE_RETRAIN=False  FORCE_TEST_SWEEP=False

# %% [markdown]
# ## Helpers

# %%
def run_tag() -> str:
    return f"n{N_TRAIN}_plain_lr1e-3_v2"


def load_meta(tag: str) -> dict:
    return json.loads((OUT / f"{tag}_meta.json").read_text(encoding="utf-8"))


def train_plain(tag: str, *, role: str = "plain_official"):
    hist_path = OUT / f"{tag}_history.npz"
    if hist_path.exists() and not FORCE_RETRAIN:
        print(f"skip {role}; using", hist_path)
        return None
    print(
        f"=== {role}: {tag}  lr={LR:g}  lam=0  "
        f"early_stop={EARLY_STOP_MODE}(patience_steps={PATIENCE_STEPS})  "
        f"max_steps={MAX_STEPS}  snap_every={SNAPSHOT_EVERY} ==="
    )
    t0 = time.perf_counter()
    result = diag.train_data_c_amb_diagnostics(
        pulse_loss_mode="raw",
        lam=0.0,
        n_train=N_TRAIN,
        n_val=N_VAL,
        n_test=N_TEST,
        batch_size=BATCH_SIZE,
        seed=SEED,
        max_epochs=int(MAX_EPOCHS),
        patience=int(PATIENCE_STEPS),
        lr=float(LR),
        train_snr_db_range=TRAIN_SNR,
        val_snr_db_range=VAL_SNR_RANGE,
        val_snr_db_values=VAL_SNR_VALUES,
        device=DEVICE,
        verbose=True,
        ambiguity_backend="legacy",
        trace_loss_ref="clean",
        loader_builder="filtered_c1",
        canonicalize_mode="t0",
        max_steps=int(MAX_STEPS),
        snapshot_every=int(SNAPSHOT_EVERY),
        snapshot_snr_db=SNAPSHOT_SNR_DB,
        snapshot_val_index=SNAPSHOT_VAL_INDEX,
        snapshot_noise_seed=SNAPSHOT_NOISE_SEED,
        early_stop_mode=EARLY_STOP_MODE,
    )
    result_save = {k: v for k, v in result.items() if k != "bundle"}
    result_save["role"] = role
    result_save["protocol"] = PROTOCOL
    diag.save_run_artifacts(result_save, OUT, tag)
    meta = load_meta(tag)
    meta["role"] = role
    meta["protocol"] = PROTOCOL
    meta["val_snr_policy"] = "discrete_{-10,0,30}"
    meta["wall_time_total_sec"] = float(time.perf_counter() - t0)
    (OUT / f"{tag}_meta.json").write_text(json.dumps(meta, indent=2), encoding="utf-8")
    print(json.dumps(meta, indent=2))
    return result


def summarize_timings(hist, name):
    keys = [
        "timing_data_prep_sec",
        "timing_loss_data_fwd_sec",
        "timing_loss_reg_fwd_sec",
        "timing_total_backward_sec",
        "timing_optimizer_step_sec",
    ]
    print(f"=== {name}: meanÂ±std over epochs (ms/batch) ===")
    for k in keys:
        if k not in hist:
            continue
        x = np.asarray(hist[k], dtype=float) * 1e3
        print(f"  {k.replace('timing_', ''):22s}  {x.mean():7.3f} Â± {x.std():6.3f}")


def plot_pulse_curves(hist, title_prefix):
    fig, axes = plt.subplots(1, 2, figsize=(12, 4))
    axes[0].plot(hist["train_pulse_l1_raw"], label="raw")
    axes[0].plot(hist["train_pulse_l1_amb"], label="best-amb")
    axes[0].set_title(f"{title_prefix}: train pulse L1")
    axes[0].set_xlabel("epoch")
    axes[0].legend()
    axes[0].grid(True, alpha=0.3)
    axes[1].plot(hist["val_pulse_l1_raw"], label="raw")
    axes[1].plot(hist["val_pulse_l1_amb"], label="best-amb")
    axes[1].set_title(f"{title_prefix}: val pulse L1 (SNRâˆˆ{{-10,0,30}})")
    axes[1].set_xlabel("epoch")
    axes[1].legend()
    axes[1].grid(True, alpha=0.3)
    plt.tight_layout()
    plt.show()
    plt.close(fig)


def plot_trace_curves(hist, title_prefix):
    fig, axes = plt.subplots(1, 2, figsize=(12, 4))
    axes[0].plot(hist["train_trace_l1"])
    axes[0].set_title(f"{title_prefix}: train TRACE L1")
    axes[0].set_xlabel("epoch")
    axes[0].grid(True, alpha=0.3)
    axes[1].plot(hist["val_trace_l1"])
    axes[1].set_title(f"{title_prefix}: val TRACE L1 (SNRâˆˆ{{-10,0,30}})")
    axes[1].set_xlabel("epoch")
    axes[1].grid(True, alpha=0.3)
    plt.tight_layout()
    plt.show()
    plt.close(fig)


def plot_grad_norms(hist, title_prefix, lam=0.0):
    fig, ax = plt.subplots(figsize=(8, 4))
    ax.semilogy(hist["grad_norm_data"], label=r"$||\nabla L_{\mathrm{data}}||$")
    ax.semilogy(
        hist["grad_norm_reg"],
        label=r"$||\nabla L_{\mathrm{reg}}||$ (NOT in loss)",
        alpha=0.7,
    )
    if "grad_norm_total" in hist and len(hist["grad_norm_total"]):
        ax.semilogy(hist["grad_norm_total"], label=r"$||\nabla L_{\mathrm{total}}||$")
    ax.set_xlabel("epoch")
    ax.set_ylabel("grad norm")
    ax.set_title(title_prefix)
    ax.legend()
    ax.grid(True, alpha=0.3)
    plt.tight_layout()
    plt.show()
    plt.close(fig)

# %% [markdown]
# ## Train plain (Î»=0, LR=1eâˆ’3, PROTOCOL v2)

# %%
TAG = run_tag()
train_plain(TAG, role="plain_official")
hist = diag.load_history(OUT / f"{TAG}_history.npz")
meta = load_meta(TAG)
print(json.dumps(meta, indent=2))
print(
    f"best_step={meta.get('best_step')}  best_epoch={meta.get('best_epoch')}  "
    f"global_step={meta.get('global_step')}  max_steps={meta.get('max_steps')}  "
    f"stopped_epoch={meta.get('stopped_epoch')}"
)
# Out:
# === plain_official: n300_plain_lr1e-3_v2  lr=0.001  lam=0  early_stop=steps(patience_steps=800)  max_steps=6400  snap_every=2 ===
# [raw|legacy] epoch 001/1280  step=5  tr_raw=7.8792  tr_amb=6.7655  va_raw=5.5277  va_amb=4.9658  tr_trace=75.11  va_trace=57.88  |g_data|=1.299e+01  |g_reg|=8.937e+00  |g_tot|=1.299e+01  t_prep=1.18ms  t_Ld=16.44ms  t_Lr=11.48ms  t_bwd=76.44ms  t_opt=10.75ms
# [raw|legacy] epoch 002/1280  step=10  tr_raw=5.2110  tr_amb=4.4784  va_raw=5.0232  va_amb=4.0595  tr_trace=52.36  va_trace=47.14  |g_data|=1.300e+01  |g_reg|=4.285e+01  |g_tot|=1.300e+01  t_prep=0.84ms  t_Ld=16.02ms  t_Lr=10.60ms  t_bwd=30.86ms  t_opt=5.28ms
# [raw|legacy] epoch 003/1280  step=15  tr_raw=4.9100  tr_amb=4.0425  va_raw=4.8667  va_amb=3.9662  tr_trace=48.84  va_trace=47.84  |g_data|=1.125e+01  |g_reg|=5.200e+01  |g_tot|=1.125e+01  t_prep=0.83ms  t_Ld=15.95ms  t_Lr=10.12ms  t_bwd=30.91ms  t_opt=5.03ms
# [raw|legacy] epoch 004/1280  step=20  tr_raw=4.7747  tr_amb=3.9162  va_raw=4.7684  va_amb=3.8754  tr_trace=48.16  va_trace=47.92  |g_data|=1.022e+01  |g_reg|=5.628e+01  |g_tot|=1.022e+01  t_prep=0.67ms  t_Ld=16.02ms  t_Lr=10.87ms  t_bwd=30.80ms  t_opt=4.90ms
# [raw|legacy] epoch 005/1280  step=25  tr_raw=4.6825  tr_amb=3.8150  va_raw=4.7496  va_amb=3.9230  tr_trace=47.29  va_trace=49.35  |g_data|=1.386e+01  |g_reg|=6.421e+01  |g_tot|=1.386e+01  t_prep=0.63ms  t_Ld=15.88ms  t_Lr=9.54ms  t_bwd=30.68ms  t_opt=4.89ms
# [raw|legacy] epoch 006/1280  step=30  tr_raw=4.6707  tr_amb=3.8514  va_raw=4.7367  va_amb=3.8353  tr_trace=48.35  va_trace=46.72  |g_data|=9.517e+00  |g_reg|=7.381e+01  |g_tot|=9.517e+00  t_prep=0.62ms  t_Ld=15.86ms  t_Lr=10.52ms  t_bwd=30.58ms  t_opt=4.89ms
# [raw|legacy] epoch 007/1280  step=35  tr_raw=4.6399  tr_amb=3.7753  va_raw=4.6732  va_amb=3.7972  tr_trace=46.87  va_trace=47.73  |g_data|=8.864e+00  |g_reg|=7.885e+01  |g_tot|=8.864e+00  t_prep=0.64ms  t_Ld=15.88ms  t_Lr=9.47ms  t_bwd=30.64ms  t_opt=4.88ms
# [raw|legacy] epoch 008/1280  step=40  tr_raw=4.6202  tr_amb=3.7854  va_raw=4.9152  va_amb=3.8010  tr_trace=47.56  va_trace=44.59  |g_data|=2.831e+01  |g_reg|=4.905e+01  |g_tot|=2.831e+01  t_prep=0.59ms  t_Ld=15.88ms  t_Lr=10.13ms  t_bwd=30.67ms  t_opt=4.99ms
# [raw|legacy] epoch 009/1280  step=45  tr_raw=4.6078  tr_amb=3.7481  va_raw=4.6651  va_amb=3.6842  tr_trace=45.69  va_trace=42.66  |g_data|=1.988e+01  |g_reg|=7.177e+01  |g_tot|=1.988e+01  t_prep=0.63ms  t_Ld=15.95ms  t_Lr=10.51ms  t_bwd=30.68ms  t_opt=4.85ms
# [raw|legacy] epoch 010/1280  step=50  tr_raw=4.5830  tr_amb=3.7376  va_raw=4.6174  va_amb=3.6585  tr_trace=45.60  va_trace=42.13  |g_data|=1.830e+01  |g_reg|=7.625e+01  |g_tot|=1.830e+01  t_prep=0.68ms  t_Ld=16.01ms  t_Lr=10.15ms  t_bwd=30.76ms  t_opt=5.00ms
# [raw|legacy] epoch 011/1280  step=55  tr_raw=4.5197  tr_amb=3.6846  va_raw=4.5261  va_amb=3.7191  tr_trace=43.88  va_trace=44.78  |g_data|=7.326e+00  |g_reg|=9.654e+01  |g_tot|=7.326e+00  t_prep=0.71ms  t_Ld=16.00ms  t_Lr=10.32ms  t_bwd=30.70ms  t_opt=5.00ms
# [raw|legacy] epoch 012/1280  step=60  tr_raw=4.4299  tr_amb=3.6704  va_raw=4.4414  va_amb=3.6388  tr_trace=44.30  va_trace=43.08  |g_data|=9.199e+00  |g_reg|=9.582e+01  |g_tot|=9.199e+00  t_prep=0.67ms  t_Ld=16.01ms  t_Lr=10.21ms  t_bwd=30.66ms  t_opt=4.94ms
# [raw|legacy] epoch 013/1280  step=65  tr_raw=4.3049  tr_amb=3.5696  va_raw=4.3203  va_amb=3.4651  tr_trace=42.57  va_trace=39.20  |g_data|=1.011e+01  |g_reg|=8.625e+01  |g_tot|=1.011e+01  t_prep=0.63ms  t_Ld=16.08ms  t_Lr=9.86ms  t_bwd=30.66ms  t_opt=4.96ms
# [raw|legacy] epoch 014/1280  step=70  tr_raw=4.1289  tr_amb=3.4234  va_raw=4.0841  va_amb=3.2215  tr_trace=40.38  va_trace=37.50  |g_data|=5.723e+00  |g_reg|=8.694e+01  |g_tot|=5.723e+00  t_prep=0.60ms  t_Ld=15.95ms  t_Lr=10.62ms  t_bwd=30.69ms  t_opt=5.01ms
# [raw|legacy] epoch 015/1280  step=75  tr_raw=3.9562  tr_amb=3.2387  va_raw=4.0079  va_amb=3.1456  tr_trace=38.17  va_trace=37.52  |g_data|=1.090e+01  |g_reg|=9.236e+01  |g_tot|=1.090e+01  t_prep=0.61ms  t_Ld=15.92ms  t_Lr=10.97ms  t_bwd=30.69ms  t_opt=5.11ms
# [raw|legacy] epoch 016/1280  step=80  tr_raw=3.9003  tr_amb=3.1651  va_raw=3.9852  va_amb=3.0667  tr_trace=37.99  va_trace=34.35  |g_data|=9.381e+00  |g_reg|=6.825e+01  |g_tot|=9.381e+00  t_prep=0.65ms  t_Ld=15.94ms  t_Lr=9.88ms  t_bwd=30.62ms  t_opt=4.96ms
# [raw|legacy] epoch 017/1280  step=85  tr_raw=3.8543  tr_amb=3.0889  va_raw=4.2160  va_amb=3.5759  tr_trace=35.78  va_trace=46.37  |g_data|=1.990e+01  |g_reg|=8.646e+01  |g_tot|=1.990e+01  t_prep=0.61ms  t_Ld=16.03ms  t_Lr=9.26ms  t_bwd=30.64ms  t_opt=4.90ms
# [raw|legacy] epoch 018/1280  step=90  tr_raw=3.8462  tr_amb=3.1237  va_raw=3.8691  va_amb=3.0709  tr_trace=37.58  va_trace=38.65  |g_data|=9.646e+00  |g_reg|=1.136e+02  |g_tot|=9.646e+00  t_prep=0.66ms  t_Ld=15.95ms  t_Lr=11.62ms  t_bwd=30.66ms  t_opt=5.10ms
# [raw|legacy] epoch 019/1280  step=95  tr_raw=3.7759  tr_amb=3.0687  va_raw=3.8246  va_amb=3.0073  tr_trace=35.88  va_trace=36.29  |g_data|=7.242e+00  |g_reg|=1.096e+02  |g_tot|=7.242e+00  t_prep=0.63ms  t_Ld=15.91ms  t_Lr=9.73ms  t_bwd=30.86ms  t_opt=5.12ms
# [raw|legacy] epoch 020/1280  step=100  tr_raw=3.7530  tr_amb=3.0040  va_raw=3.8559  va_amb=3.0119  tr_trace=34.65  va_trace=35.75  |g_data|=9.816e+00  |g_reg|=1.032e+02  |g_tot|=9.816e+00  t_prep=0.69ms  t_Ld=16.06ms  t_Lr=10.62ms  t_bwd=30.68ms  t_opt=4.97ms
# [raw|legacy] epoch 021/1280  step=105  tr_raw=3.7125  tr_amb=2.9904  va_raw=3.7931  va_amb=2.9158  tr_trace=34.38  va_trace=31.99  |g_data|=7.867e+00  |g_reg|=5.451e+01  |g_tot|=7.867e+00  t_prep=0.68ms  t_Ld=16.01ms  t_Lr=11.63ms  t_bwd=30.82ms  t_opt=4.88ms
# [raw|legacy] epoch 022/1280  step=110  tr_raw=3.6705  tr_amb=2.9531  va_raw=3.8027  va_amb=2.9353  tr_trace=34.44  va_trace=34.03  |g_data|=6.649e+00  |g_reg|=3.449e+01  |g_tot|=6.649e+00  t_prep=0.63ms  t_Ld=15.96ms  t_Lr=9.97ms  t_bwd=30.70ms  t_opt=5.00ms
# [raw|legacy] epoch 023/1280  step=115  tr_raw=3.6360  tr_amb=2.9059  va_raw=3.7950  va_amb=2.9977  tr_trace=33.31  va_trace=35.49  |g_data|=1.059e+01  |g_reg|=1.046e+02  |g_tot|=1.059e+01  t_prep=0.70ms  t_Ld=15.94ms  t_Lr=10.42ms  t_bwd=30.84ms  t_opt=4.92ms
# [raw|legacy] epoch 024/1280  step=120  tr_raw=3.6296  tr_amb=2.9088  va_raw=3.7450  va_amb=2.8897  tr_trace=33.36  va_trace=33.71  |g_data|=5.407e+00  |g_reg|=9.401e+01  |g_tot|=5.407e+00  t_prep=0.82ms  t_Ld=16.10ms  t_Lr=11.23ms  t_bwd=30.74ms  t_opt=4.90ms
# [raw|legacy] epoch 025/1280  step=125  tr_raw=3.5865  tr_amb=2.8776  va_raw=3.7377  va_amb=2.8609  tr_trace=32.44  va_trace=33.68  |g_data|=7.364e+00  |g_reg|=1.172e+02  |g_tot|=7.364e+00  t_prep=0.73ms  t_Ld=15.98ms  t_Lr=10.66ms  t_bwd=30.89ms  t_opt=4.95ms
# [raw|legacy] epoch 026/1280  step=130  tr_raw=3.5464  tr_amb=2.8229  va_raw=3.7773  va_amb=3.0135  tr_trace=31.61  va_trace=39.86  |g_data|=1.216e+01  |g_reg|=1.223e+02  |g_tot|=1.216e+01  t_prep=0.68ms  t_Ld=15.98ms  t_Lr=9.77ms  t_bwd=30.74ms  t_opt=4.99ms
# [raw|legacy] epoch 027/1280  step=135  tr_raw=3.5282  tr_amb=2.8370  va_raw=3.7268  va_amb=2.8025  tr_trace=33.02  va_trace=30.18  |g_data|=1.231e+01  |g_reg|=4.697e+01  |g_tot|=1.231e+01  t_prep=0.70ms  t_Ld=15.96ms  t_Lr=9.69ms  t_bwd=30.85ms  t_opt=4.96ms
# [raw|legacy] epoch 028/1280  step=140  tr_raw=3.5204  tr_amb=2.7956  va_raw=3.7862  va_amb=2.9504  tr_trace=30.94  va_trace=36.71  |g_data|=7.328e+00  |g_reg|=1.178e+02  |g_tot|=7.328e+00  t_prep=0.62ms  t_Ld=15.96ms  t_Lr=10.47ms  t_bwd=30.77ms  t_opt=4.92ms
# [raw|legacy] epoch 029/1280  step=145  tr_raw=3.4801  tr_amb=2.7948  va_raw=3.7457  va_amb=2.9180  tr_trace=31.87  va_trace=35.86  |g_data|=6.613e+00  |g_reg|=1.212e+02  |g_tot|=6.613e+00  t_prep=0.61ms  t_Ld=15.96ms  t_Lr=9.78ms  t_bwd=30.76ms  t_opt=4.89ms
# [raw|legacy] epoch 030/1280  step=150  tr_raw=3.4499  tr_amb=2.7669  va_raw=3.7043  va_amb=2.8414  tr_trace=31.23  va_trace=34.43  |g_data|=6.984e+00  |g_reg|=1.215e+02  |g_tot|=6.984e+00  t_prep=0.59ms  t_Ld=15.93ms  t_Lr=9.89ms  t_bwd=30.65ms  t_opt=4.86ms
# [raw|legacy] epoch 031/1280  step=155  tr_raw=3.4158  tr_amb=2.7197  va_raw=3.7022  va_amb=2.8115  tr_trace=30.54  va_trace=31.36  |g_data|=7.787e+00  |g_reg|=7.605e+01  |g_tot|=7.787e+00  t_prep=0.71ms  t_Ld=15.97ms  t_Lr=8.99ms  t_bwd=30.79ms  t_opt=4.85ms
# [raw|legacy] epoch 032/1280  step=160  tr_raw=3.4100  tr_amb=2.7292  va_raw=3.6983  va_amb=2.7558  tr_trace=31.46  va_trace=29.72  |g_data|=1.966e+01  |g_reg|=9.815e+01  |g_tot|=1.966e+01  t_prep=0.61ms  t_Ld=15.93ms  t_Lr=9.49ms  t_bwd=30.85ms  t_opt=4.85ms
# [raw|legacy] epoch 033/1280  step=165  tr_raw=3.4088  tr_amb=2.7250  va_raw=3.6772  va_amb=2.7626  tr_trace=31.47  va_trace=31.97  |g_data|=1.184e+01  |g_reg|=1.228e+02  |g_tot|=1.184e+01  t_prep=0.70ms  t_Ld=16.21ms  t_Lr=11.32ms  t_bwd=30.86ms  t_opt=5.02ms
# [raw|legacy] epoch 034/1280  step=170  tr_raw=3.3757  tr_amb=2.6984  va_raw=3.6729  va_amb=2.7758  tr_trace=31.39  va_trace=30.34  |g_data|=1.006e+01  |g_reg|=8.741e+01  |g_tot|=1.006e+01  t_prep=0.62ms  t_Ld=16.00ms  t_Lr=10.54ms  t_bwd=30.97ms  t_opt=5.04ms
# [raw|legacy] epoch 035/1280  step=175  tr_raw=3.3998  tr_amb=2.7423  va_raw=3.6775  va_amb=2.7332  tr_trace=30.53  va_trace=30.14  |g_data|=1.072e+01  |g_reg|=2.870e+01  |g_tot|=1.072e+01  t_prep=0.69ms  t_Ld=16.02ms  t_Lr=9.98ms  t_bwd=30.86ms  t_opt=5.16ms
# [raw|legacy] epoch 036/1280  step=180  tr_raw=3.3744  tr_amb=2.7003  va_raw=3.6889  va_amb=2.8077  tr_trace=30.27  va_trace=33.67  |g_data|=1.514e+01  |g_reg|=1.235e+02  |g_tot|=1.514e+01  t_prep=0.68ms  t_Ld=16.02ms  t_Lr=10.49ms  t_bwd=30.96ms  t_opt=4.88ms
# [raw|legacy] epoch 037/1280  step=185  tr_raw=3.3309  tr_amb=2.6608  va_raw=3.6449  va_amb=2.7541  tr_trace=30.73  va_trace=33.52  |g_data|=9.563e+00  |g_reg|=1.331e+02  |g_tot|=9.563e+00  t_prep=0.63ms  t_Ld=15.96ms  t_Lr=10.80ms  t_bwd=30.83ms  t_opt=4.94ms
# [raw|legacy] epoch 038/1280  step=190  tr_raw=3.3096  tr_amb=2.6848  va_raw=3.6739  va_amb=2.6885  tr_trace=30.59  va_trace=28.86  |g_data|=1.494e+01  |g_reg|=6.186e+01  |g_tot|=1.494e+01  t_prep=0.65ms  t_Ld=16.02ms  t_Lr=10.84ms  t_bwd=30.94ms  t_opt=5.01ms
# [raw|legacy] epoch 039/1280  step=195  tr_raw=3.2967  tr_amb=2.6455  va_raw=3.7455  va_amb=2.8117  tr_trace=29.80  va_trace=32.02  |g_data|=1.404e+01  |g_reg|=6.041e+01  |g_tot|=1.404e+01  t_prep=0.66ms  t_Ld=16.04ms  t_Lr=9.68ms  t_bwd=30.93ms  t_opt=5.15ms
# [raw|legacy] epoch 040/1280  step=200  tr_raw=3.2519  tr_amb=2.5888  va_raw=3.6917  va_amb=2.7183  tr_trace=29.63  va_trace=28.92  |g_data|=9.503e+00  |g_reg|=5.291e+01  |g_tot|=9.503e+00  t_prep=0.71ms  t_Ld=16.06ms  t_Lr=9.34ms  t_bwd=30.81ms  t_opt=4.93ms
# [raw|legacy] epoch 041/1280  step=205  tr_raw=3.2195  tr_amb=2.5698  va_raw=3.6663  va_amb=2.7185  tr_trace=29.50  va_trace=32.89  |g_data|=1.066e+01  |g_reg|=1.182e+02  |g_tot|=1.066e+01  t_prep=0.73ms  t_Ld=16.07ms  t_Lr=10.78ms  t_bwd=30.83ms  t_opt=4.94ms
# [raw|legacy] epoch 042/1280  step=210  tr_raw=3.1855  tr_amb=2.5252  va_raw=3.6081  va_amb=2.6659  tr_trace=28.19  va_trace=30.99  |g_data|=9.304e+00  |g_reg|=8.247e+01  |g_tot|=9.304e+00  t_prep=0.71ms  t_Ld=16.05ms  t_Lr=10.36ms  t_bwd=30.88ms  t_opt=5.03ms
# [raw|legacy] epoch 043/1280  step=215  tr_raw=3.1486  tr_amb=2.5004  va_raw=3.6066  va_amb=2.6925  tr_trace=28.88  va_trace=32.39  |g_data|=9.901e+00  |g_reg|=1.132e+02  |g_tot|=9.901e+00  t_prep=0.71ms  t_Ld=16.07ms  t_Lr=10.23ms  t_bwd=30.71ms  t_opt=4.90ms
# [raw|legacy] epoch 044/1280  step=220  tr_raw=3.1156  tr_amb=2.4484  va_raw=3.6082  va_amb=2.6796  tr_trace=27.98  va_trace=34.97  |g_data|=1.458e+01  |g_reg|=1.208e+02  |g_tot|=1.458e+01  t_prep=0.68ms  t_Ld=16.03ms  t_Lr=10.87ms  t_bwd=30.80ms  t_opt=5.19ms
# [raw|legacy] epoch 045/1280  step=225  tr_raw=3.0986  tr_amb=2.4653  va_raw=3.5557  va_amb=2.5082  tr_trace=30.16  va_trace=28.21  |g_data|=6.351e+00  |g_reg|=8.974e+01  |g_tot|=6.351e+00  t_prep=0.72ms  t_Ld=15.96ms  t_Lr=10.85ms  t_bwd=30.79ms  t_opt=5.02ms
# [raw|legacy] epoch 046/1280  step=230  tr_raw=3.0567  tr_amb=2.4256  va_raw=3.5915  va_amb=2.5280  tr_trace=28.34  va_trace=26.31  |g_data|=1.338e+01  |g_reg|=1.413e+01  |g_tot|=1.338e+01  t_prep=0.67ms  t_Ld=16.03ms  t_Lr=10.97ms  t_bwd=30.96ms  t_opt=4.99ms
# [raw|legacy] epoch 047/1280  step=235  tr_raw=3.0088  tr_amb=2.3751  va_raw=3.5754  va_amb=2.5372  tr_trace=26.47  va_trace=26.97  |g_data|=7.575e+00  |g_reg|=2.358e+01  |g_tot|=7.575e+00  t_prep=0.75ms  t_Ld=16.10ms  t_Lr=9.52ms  t_bwd=30.80ms  t_opt=5.12ms
# [raw|legacy] epoch 048/1280  step=240  tr_raw=2.9449  tr_amb=2.3430  va_raw=3.5097  va_amb=2.5853  tr_trace=26.31  va_trace=29.63  |g_data|=9.985e+00  |g_reg|=9.436e+01  |g_tot|=9.985e+00  t_prep=0.66ms  t_Ld=16.13ms  t_Lr=9.83ms  t_bwd=30.93ms  t_opt=4.88ms
# [raw|legacy] epoch 049/1280  step=245  tr_raw=2.9307  tr_amb=2.3374  va_raw=3.6667  va_amb=2.7071  tr_trace=26.92  va_trace=34.08  |g_data|=1.399e+01  |g_reg|=1.126e+02  |g_tot|=1.399e+01  t_prep=0.64ms  t_Ld=16.02ms  t_Lr=10.23ms  t_bwd=30.73ms  t_opt=4.92ms
# [raw|legacy] epoch 050/1280  step=250  tr_raw=2.8965  tr_amb=2.3037  va_raw=3.5080  va_amb=2.5606  tr_trace=26.60  va_trace=32.96  |g_data|=1.551e+01  |g_reg|=1.375e+02  |g_tot|=1.551e+01  t_prep=0.72ms  t_Ld=15.94ms  t_Lr=10.25ms  t_bwd=30.76ms  t_opt=4.90ms
# [raw|legacy] epoch 051/1280  step=255  tr_raw=2.8851  tr_amb=2.3106  va_raw=3.6546  va_amb=2.6255  tr_trace=26.58  va_trace=31.41  |g_data|=1.163e+01  |g_reg|=9.675e+01  |g_tot|=1.163e+01  t_prep=0.71ms  t_Ld=16.18ms  t_Lr=10.27ms  t_bwd=30.74ms  t_opt=4.91ms
# [raw|legacy] epoch 052/1280  step=260  tr_raw=2.8346  tr_amb=2.2758  va_raw=3.6354  va_amb=2.5502  tr_trace=26.11  va_trace=27.45  |g_data|=7.033e+00  |g_reg|=5.973e+01  |g_tot|=7.033e+00  t_prep=0.72ms  t_Ld=16.01ms  t_Lr=9.84ms  t_bwd=30.74ms  t_opt=4.91ms
# [raw|legacy] epoch 053/1280  step=265  tr_raw=2.7904  tr_amb=2.2398  va_raw=3.5891  va_amb=2.4370  tr_trace=24.79  va_trace=27.40  |g_data|=8.149e+00  |g_reg|=2.595e+01  |g_tot|=8.149e+00  t_prep=0.70ms  t_Ld=15.97ms  t_Lr=10.42ms  t_bwd=30.92ms  t_opt=4.97ms
# [raw|legacy] epoch 054/1280  step=270  tr_raw=2.7439  tr_amb=2.2058  va_raw=3.6131  va_amb=2.5783  tr_trace=26.55  va_trace=28.79  |g_data|=7.854e+00  |g_reg|=2.263e+01  |g_tot|=7.854e+00  t_prep=0.73ms  t_Ld=16.00ms  t_Lr=9.46ms  t_bwd=30.72ms  t_opt=4.89ms
# [raw|legacy] epoch 055/1280  step=275  tr_raw=2.7048  tr_amb=2.1968  va_raw=3.6507  va_amb=2.5730  tr_trace=24.49  va_trace=29.47  |g_data|=8.836e+00  |g_reg|=7.110e+01  |g_tot|=8.836e+00  t_prep=0.68ms  t_Ld=16.11ms  t_Lr=10.07ms  t_bwd=30.79ms  t_opt=5.16ms
# [raw|legacy] epoch 056/1280  step=280  tr_raw=2.6730  tr_amb=2.1482  va_raw=3.6063  va_amb=2.6053  tr_trace=24.43  va_trace=33.53  |g_data|=1.441e+01  |g_reg|=1.219e+02  |g_tot|=1.441e+01  t_prep=0.69ms  t_Ld=15.95ms  t_Lr=10.81ms  t_bwd=30.80ms  t_opt=4.98ms
# [raw|legacy] epoch 057/1280  step=285  tr_raw=2.6730  tr_amb=2.1699  va_raw=3.6124  va_amb=2.5368  tr_trace=25.62  va_trace=27.32  |g_data|=8.627e+00  |g_reg|=1.766e+01  |g_tot|=8.627e+00  t_prep=0.89ms  t_Ld=16.12ms  t_Lr=9.51ms  t_bwd=30.84ms  t_opt=4.98ms
# [raw|legacy] epoch 058/1280  step=290  tr_raw=2.6402  tr_amb=2.1362  va_raw=3.6130  va_amb=2.5382  tr_trace=25.50  va_trace=29.24  |g_data|=8.635e+00  |g_reg|=1.258e+02  |g_tot|=8.635e+00  t_prep=0.59ms  t_Ld=15.99ms  t_Lr=10.36ms  t_bwd=30.79ms  t_opt=4.95ms
# [raw|legacy] epoch 059/1280  step=295  tr_raw=2.6021  tr_amb=2.1220  va_raw=3.5801  va_amb=2.4699  tr_trace=24.56  va_trace=26.28  |g_data|=1.083e+01  |g_reg|=4.090e+01  |g_tot|=1.083e+01  t_prep=0.72ms  t_Ld=15.99ms  t_Lr=9.67ms  t_bwd=30.76ms  t_opt=5.01ms
# [raw|legacy] epoch 060/1280  step=300  tr_raw=2.5454  tr_amb=2.0787  va_raw=3.6769  va_amb=2.6255  tr_trace=23.42  va_trace=29.14  |g_data|=1.254e+01  |g_reg|=4.412e+01  |g_tot|=1.254e+01  t_prep=0.66ms  t_Ld=16.00ms  t_Lr=10.04ms  t_bwd=30.88ms  t_opt=5.07ms
# [raw|legacy] epoch 061/1280  step=305  tr_raw=2.5009  tr_amb=2.0364  va_raw=3.6012  va_amb=2.5140  tr_trace=22.83  va_trace=26.68  |g_data|=9.840e+00  |g_reg|=5.663e+01  |g_tot|=9.840e+00  t_prep=0.61ms  t_Ld=15.95ms  t_Lr=10.01ms  t_bwd=30.89ms  t_opt=4.87ms
# [raw|legacy] epoch 062/1280  step=310  tr_raw=2.4634  tr_amb=2.0329  va_raw=3.5357  va_amb=2.3949  tr_trace=22.97  va_trace=24.54  |g_data|=7.503e+00  |g_reg|=6.877e+01  |g_tot|=7.503e+00  t_prep=0.86ms  t_Ld=16.15ms  t_Lr=10.36ms  t_bwd=30.78ms  t_opt=5.13ms
# [raw|legacy] epoch 063/1280  step=315  tr_raw=2.4243  tr_amb=1.9947  va_raw=3.5381  va_amb=2.3902  tr_trace=22.85  va_trace=25.60  |g_data|=7.280e+00  |g_reg|=2.613e+01  |g_tot|=7.280e+00  t_prep=0.64ms  t_Ld=16.01ms  t_Lr=10.31ms  t_bwd=30.95ms  t_opt=5.02ms
# [raw|legacy] epoch 064/1280  step=320  tr_raw=2.3803  tr_amb=1.9642  va_raw=3.6157  va_amb=2.5378  tr_trace=21.90  va_trace=32.35  |g_data|=9.837e+00  |g_reg|=1.209e+02  |g_tot|=9.837e+00  t_prep=0.62ms  t_Ld=15.98ms  t_Lr=9.83ms  t_bwd=30.87ms  t_opt=5.20ms
# [raw|legacy] epoch 065/1280  step=325  tr_raw=2.3397  tr_amb=1.9764  va_raw=3.6178  va_amb=2.5362  tr_trace=23.91  va_trace=29.65  |g_data|=1.817e+01  |g_reg|=1.140e+02  |g_tot|=1.817e+01  t_prep=0.71ms  t_Ld=16.07ms  t_Lr=10.23ms  t_bwd=30.84ms  t_opt=4.87ms
# [raw|legacy] epoch 066/1280  step=330  tr_raw=2.3471  tr_amb=1.9824  va_raw=3.6200  va_amb=2.5205  tr_trace=24.76  va_trace=26.92  |g_data|=8.251e+00  |g_reg|=2.786e+01  |g_tot|=8.251e+00  t_prep=0.66ms  t_Ld=15.99ms  t_Lr=10.57ms  t_bwd=30.78ms  t_opt=5.18ms
# [raw|legacy] epoch 067/1280  step=335  tr_raw=2.3328  tr_amb=1.9682  va_raw=3.5969  va_amb=2.4579  tr_trace=23.62  va_trace=25.77  |g_data|=9.259e+00  |g_reg|=3.431e+01  |g_tot|=9.259e+00  t_prep=0.74ms  t_Ld=15.95ms  t_Lr=10.38ms  t_bwd=30.92ms  t_opt=5.00ms
# [raw|legacy] epoch 068/1280  step=340  tr_raw=2.3370  tr_amb=1.9589  va_raw=3.6280  va_amb=2.6089  tr_trace=22.79  va_trace=27.56  |g_data|=1.139e+01  |g_reg|=3.691e+01  |g_tot|=1.139e+01  t_prep=0.71ms  t_Ld=15.96ms  t_Lr=10.89ms  t_bwd=31.22ms  t_opt=5.06ms
# [raw|legacy] epoch 069/1280  step=345  tr_raw=2.2267  tr_amb=1.8653  va_raw=3.5797  va_amb=2.3967  tr_trace=21.75  va_trace=23.78  |g_data|=1.058e+01  |g_reg|=4.681e+01  |g_tot|=1.058e+01  t_prep=0.79ms  t_Ld=16.12ms  t_Lr=12.89ms  t_bwd=32.07ms  t_opt=5.09ms
# [raw|legacy] epoch 070/1280  step=350  tr_raw=2.1649  tr_amb=1.8515  va_raw=3.5728  va_amb=2.3949  tr_trace=21.39  va_trace=26.04  |g_data|=7.866e+00  |g_reg|=8.631e+01  |g_tot|=7.866e+00  t_prep=0.82ms  t_Ld=16.78ms  t_Lr=11.74ms  t_bwd=32.28ms  t_opt=5.01ms
# [raw|legacy] epoch 071/1280  step=355  tr_raw=2.0501  tr_amb=1.7676  va_raw=3.6875  va_amb=2.5546  tr_trace=20.78  va_trace=28.95  |g_data|=9.699e+00  |g_reg|=1.088e+02  |g_tot|=9.699e+00  t_prep=0.73ms  t_Ld=16.89ms  t_Lr=12.09ms  t_bwd=33.85ms  t_opt=5.23ms
# [raw|legacy] epoch 072/1280  step=360  tr_raw=1.9621  tr_amb=1.7055  va_raw=3.5960  va_amb=2.5020  tr_trace=20.15  va_trace=27.80  |g_data|=1.206e+01  |g_reg|=9.777e+01  |g_tot|=1.206e+01  t_prep=0.72ms  t_Ld=17.02ms  t_Lr=12.61ms  t_bwd=32.64ms  t_opt=4.98ms
# [raw|legacy] epoch 073/1280  step=365  tr_raw=1.9905  tr_amb=1.7293  va_raw=3.6702  va_amb=2.4878  tr_trace=20.55  va_trace=27.64  |g_data|=1.221e+01  |g_reg|=9.997e+01  |g_tot|=1.221e+01  t_prep=0.63ms  t_Ld=16.63ms  t_Lr=10.73ms  t_bwd=31.84ms  t_opt=5.29ms
# [raw|legacy] epoch 074/1280  step=370  tr_raw=1.9512  tr_amb=1.7087  va_raw=3.7749  va_amb=2.6011  tr_trace=19.58  va_trace=26.90  |g_data|=9.196e+00  |g_reg|=6.272e+01  |g_tot|=9.196e+00  t_prep=0.71ms  t_Ld=16.72ms  t_Lr=11.92ms  t_bwd=32.19ms  t_opt=5.11ms
# [raw|legacy] epoch 075/1280  step=375  tr_raw=1.8797  tr_amb=1.6399  va_raw=3.7490  va_amb=2.6607  tr_trace=18.67  va_trace=29.89  |g_data|=1.249e+01  |g_reg|=6.750e+01  |g_tot|=1.249e+01  t_prep=0.95ms  t_Ld=17.98ms  t_Lr=10.52ms  t_bwd=35.79ms  t_opt=5.04ms
# [raw|legacy] epoch 076/1280  step=380  tr_raw=1.8110  tr_amb=1.6129  va_raw=3.7745  va_amb=2.5838  tr_trace=17.91  va_trace=27.55  |g_data|=8.056e+00  |g_reg|=2.601e+01  |g_tot|=8.056e+00  t_prep=0.69ms  t_Ld=16.57ms  t_Lr=10.74ms  t_bwd=31.98ms  t_opt=5.20ms
# [raw|legacy] epoch 077/1280  step=385  tr_raw=1.8071  tr_amb=1.5998  va_raw=3.6543  va_amb=2.4724  tr_trace=18.13  va_trace=26.12  |g_data|=1.014e+01  |g_reg|=1.779e+01  |g_tot|=1.014e+01  t_prep=0.74ms  t_Ld=17.01ms  t_Lr=10.72ms  t_bwd=32.17ms  t_opt=5.25ms
# [raw|legacy] epoch 078/1280  step=390  tr_raw=1.8565  tr_amb=1.6507  va_raw=3.6981  va_amb=2.4355  tr_trace=19.21  va_trace=24.60  |g_data|=1.071e+01  |g_reg|=5.199e+01  |g_tot|=1.071e+01  t_prep=0.72ms  t_Ld=17.02ms  t_Lr=11.93ms  t_bwd=32.72ms  t_opt=5.14ms
# [raw|legacy] epoch 079/1280  step=395  tr_raw=1.8133  tr_amb=1.6084  va_raw=3.7770  va_amb=2.7398  tr_trace=18.72  va_trace=30.95  |g_data|=1.131e+01  |g_reg|=4.947e+01  |g_tot|=1.131e+01  t_prep=0.66ms  t_Ld=16.66ms  t_Lr=10.94ms  t_bwd=31.97ms  t_opt=5.11ms
# [raw|legacy] epoch 080/1280  step=400  tr_raw=1.7342  tr_amb=1.5477  va_raw=3.7423  va_amb=2.5344  tr_trace=17.52  va_trace=27.67  |g_data|=1.074e+01  |g_reg|=5.033e+01  |g_tot|=1.074e+01  t_prep=0.82ms  t_Ld=16.58ms  t_Lr=12.31ms  t_bwd=31.76ms  t_opt=5.09ms
# [raw|legacy] epoch 081/1280  step=405  tr_raw=1.7123  tr_amb=1.5350  va_raw=3.7264  va_amb=2.6674  tr_trace=17.34  va_trace=31.69  |g_data|=8.219e+00  |g_reg|=5.992e+01  |g_tot|=8.219e+00  t_prep=0.72ms  t_Ld=16.03ms  t_Lr=11.90ms  t_bwd=30.97ms  t_opt=5.03ms
# [raw|legacy] epoch 082/1280  step=410  tr_raw=1.6880  tr_amb=1.5118  va_raw=3.7308  va_amb=2.6619  tr_trace=17.90  va_trace=29.70  |g_data|=9.524e+00  |g_reg|=4.063e+01  |g_tot|=9.524e+00  t_prep=0.69ms  t_Ld=16.78ms  t_Lr=10.98ms  t_bwd=32.05ms  t_opt=5.01ms
# [raw|legacy] epoch 083/1280  step=415  tr_raw=1.6374  tr_amb=1.4758  va_raw=3.6840  va_amb=2.3625  tr_trace=17.91  va_trace=23.89  |g_data|=1.556e+01  |g_reg|=9.563e+01  |g_tot|=1.556e+01  t_prep=0.77ms  t_Ld=16.04ms  t_Lr=10.20ms  t_bwd=30.79ms  t_opt=4.96ms
# [raw|legacy] epoch 084/1280  step=420  tr_raw=1.5670  tr_amb=1.4246  va_raw=3.7037  va_amb=2.5490  tr_trace=16.78  va_trace=28.11  |g_data|=9.543e+00  |g_reg|=5.260e+01  |g_tot|=9.543e+00  t_prep=0.75ms  t_Ld=16.07ms  t_Lr=11.18ms  t_bwd=30.82ms  t_opt=4.86ms
# [raw|legacy] epoch 085/1280  step=425  tr_raw=1.5145  tr_amb=1.3741  va_raw=3.6985  va_amb=2.5851  tr_trace=15.94  va_trace=29.03  |g_data|=9.311e+00  |g_reg|=7.884e+01  |g_tot|=9.311e+00  t_prep=0.60ms  t_Ld=15.96ms  t_Lr=9.97ms  t_bwd=30.83ms  t_opt=5.15ms
# [raw|legacy] epoch 086/1280  step=430  tr_raw=1.4924  tr_amb=1.3689  va_raw=3.6903  va_amb=2.5309  tr_trace=16.63  va_trace=26.98  |g_data|=8.941e+00  |g_reg|=1.721e+01  |g_tot|=8.941e+00  t_prep=0.65ms  t_Ld=16.02ms  t_Lr=12.35ms  t_bwd=30.97ms  t_opt=4.94ms
# [raw|legacy] epoch 087/1280  step=435  tr_raw=1.5223  tr_amb=1.3899  va_raw=3.7840  va_amb=2.5922  tr_trace=16.45  va_trace=26.88  |g_data|=1.441e+01  |g_reg|=2.486e+01  |g_tot|=1.441e+01  t_prep=0.62ms  t_Ld=16.02ms  t_Lr=10.59ms  t_bwd=30.80ms  t_opt=4.97ms
# [raw|legacy] epoch 088/1280  step=440  tr_raw=1.5444  tr_amb=1.4097  va_raw=3.8475  va_amb=2.6789  tr_trace=16.38  va_trace=29.60  |g_data|=8.673e+00  |g_reg|=2.633e+01  |g_tot|=8.673e+00  t_prep=0.76ms  t_Ld=16.08ms  t_Lr=9.93ms  t_bwd=30.90ms  t_opt=5.03ms
# [raw|legacy] epoch 089/1280  step=445  tr_raw=1.5913  tr_amb=1.4289  va_raw=3.7269  va_amb=2.4974  tr_trace=17.19  va_trace=27.33  |g_data|=1.491e+01  |g_reg|=7.998e+01  |g_tot|=1.491e+01  t_prep=0.80ms  t_Ld=16.04ms  t_Lr=12.90ms  t_bwd=30.93ms  t_opt=5.14ms
# [raw|legacy] epoch 090/1280  step=450  tr_raw=1.5111  tr_amb=1.3845  va_raw=3.6515  va_amb=2.3875  tr_trace=17.57  va_trace=25.12  |g_data|=1.102e+01  |g_reg|=7.569e+01  |g_tot|=1.102e+01  t_prep=0.70ms  t_Ld=16.01ms  t_Lr=10.41ms  t_bwd=30.81ms  t_opt=5.20ms
# [raw|legacy] epoch 091/1280  step=455  tr_raw=1.5696  tr_amb=1.4260  va_raw=3.7731  va_amb=2.5115  tr_trace=18.85  va_trace=26.90  |g_data|=9.284e+00  |g_reg|=2.382e+01  |g_tot|=9.284e+00  t_prep=0.68ms  t_Ld=16.01ms  t_Lr=10.62ms  t_bwd=30.86ms  t_opt=5.01ms
# [raw|legacy] epoch 092/1280  step=460  tr_raw=1.4192  tr_amb=1.2983  va_raw=3.8299  va_amb=2.6090  tr_trace=15.86  va_trace=29.02  |g_data|=1.110e+01  |g_reg|=4.776e+01  |g_tot|=1.110e+01  t_prep=0.68ms  t_Ld=16.54ms  t_Lr=10.02ms  t_bwd=31.78ms  t_opt=4.87ms
# [raw|legacy] epoch 093/1280  step=465  tr_raw=1.4265  tr_amb=1.3163  va_raw=3.8061  va_amb=2.7251  tr_trace=17.75  va_trace=33.68  |g_data|=1.367e+01  |g_reg|=6.203e+01  |g_tot|=1.367e+01  t_prep=0.65ms  t_Ld=16.18ms  t_Lr=9.57ms  t_bwd=30.84ms  t_opt=4.98ms
# [raw|legacy] epoch 094/1280  step=470  tr_raw=1.3636  tr_amb=1.2581  va_raw=3.8611  va_amb=2.7253  tr_trace=16.65  va_trace=32.31  |g_data|=1.415e+01  |g_reg|=1.069e+02  |g_tot|=1.415e+01  t_prep=0.72ms  t_Ld=16.26ms  t_Lr=10.46ms  t_bwd=30.77ms  t_opt=4.96ms
# [raw|legacy] epoch 095/1280  step=475  tr_raw=1.3530  tr_amb=1.2544  va_raw=3.8594  va_amb=2.6904  tr_trace=16.00  va_trace=29.94  |g_data|=8.744e+00  |g_reg|=3.836e+01  |g_tot|=8.744e+00  t_prep=0.57ms  t_Ld=15.94ms  t_Lr=8.80ms  t_bwd=30.85ms  t_opt=4.80ms
# [raw|legacy] epoch 096/1280  step=480  tr_raw=1.3694  tr_amb=1.2849  va_raw=3.8383  va_amb=2.5804  tr_trace=18.12  va_trace=27.55  |g_data|=1.671e+01  |g_reg|=1.099e+02  |g_tot|=1.671e+01  t_prep=0.57ms  t_Ld=15.93ms  t_Lr=8.66ms  t_bwd=30.81ms  t_opt=4.68ms
# [raw|legacy] epoch 097/1280  step=485  tr_raw=1.2703  tr_amb=1.1885  va_raw=3.7076  va_amb=2.4027  tr_trace=15.57  va_trace=24.22  |g_data|=1.024e+01  |g_reg|=5.066e+01  |g_tot|=1.024e+01  t_prep=0.60ms  t_Ld=15.94ms  t_Lr=9.13ms  t_bwd=30.81ms  t_opt=4.73ms
# [raw|legacy] epoch 098/1280  step=490  tr_raw=1.2593  tr_amb=1.1813  va_raw=3.7935  va_amb=2.6297  tr_trace=15.00  va_trace=28.72  |g_data|=8.099e+00  |g_reg|=3.607e+01  |g_tot|=8.099e+00  t_prep=0.62ms  t_Ld=16.11ms  t_Lr=9.72ms  t_bwd=30.79ms  t_opt=4.83ms
# [raw|legacy] epoch 099/1280  step=495  tr_raw=1.2406  tr_amb=1.1530  va_raw=3.7888  va_amb=2.6468  tr_trace=13.63  va_trace=29.94  |g_data|=7.997e+00  |g_reg|=3.202e+01  |g_tot|=7.997e+00  t_prep=0.59ms  t_Ld=15.97ms  t_Lr=9.63ms  t_bwd=30.82ms  t_opt=4.78ms
# [raw|legacy] epoch 100/1280  step=500  tr_raw=1.2416  tr_amb=1.1526  va_raw=3.7699  va_amb=2.5212  tr_trace=14.55  va_trace=25.85  |g_data|=1.111e+01  |g_reg|=5.522e+01  |g_tot|=1.111e+01  t_prep=0.67ms  t_Ld=15.96ms  t_Lr=10.20ms  t_bwd=30.79ms  t_opt=4.80ms
# [raw|legacy] epoch 101/1280  step=505  tr_raw=1.2280  tr_amb=1.1423  va_raw=3.7208  va_amb=2.5445  tr_trace=14.26  va_trace=27.31  |g_data|=1.020e+01  |g_reg|=1.862e+01  |g_tot|=1.020e+01  t_prep=0.58ms  t_Ld=15.98ms  t_Lr=9.27ms  t_bwd=30.81ms  t_opt=4.81ms
# [raw|legacy] epoch 102/1280  step=510  tr_raw=1.1736  tr_amb=1.0916  va_raw=3.7539  va_amb=2.4487  tr_trace=12.85  va_trace=25.30  |g_data|=9.065e+00  |g_reg|=1.852e+01  |g_tot|=9.065e+00  t_prep=0.61ms  t_Ld=15.97ms  t_Lr=8.92ms  t_bwd=30.87ms  t_opt=4.91ms
# [raw|legacy] epoch 103/1280  step=515  tr_raw=1.2992  tr_amb=1.1930  va_raw=3.8462  va_amb=2.5899  tr_trace=14.28  va_trace=28.02  |g_data|=1.080e+01  |g_reg|=4.799e+01  |g_tot|=1.080e+01  t_prep=0.67ms  t_Ld=15.93ms  t_Lr=8.88ms  t_bwd=30.74ms  t_opt=4.70ms
# [raw|legacy] epoch 104/1280  step=520  tr_raw=1.2028  tr_amb=1.1265  va_raw=3.7059  va_amb=2.4412  tr_trace=14.29  va_trace=25.96  |g_data|=1.096e+01  |g_reg|=5.024e+01  |g_tot|=1.096e+01  t_prep=0.60ms  t_Ld=15.92ms  t_Lr=8.92ms  t_bwd=30.84ms  t_opt=4.99ms
# [raw|legacy] epoch 105/1280  step=525  tr_raw=1.1708  tr_amb=1.0899  va_raw=3.6898  va_amb=2.4227  tr_trace=13.62  va_trace=25.42  |g_data|=8.996e+00  |g_reg|=5.713e+01  |g_tot|=8.996e+00  t_prep=0.62ms  t_Ld=15.89ms  t_Lr=8.96ms  t_bwd=30.77ms  t_opt=4.81ms
# [raw|legacy] epoch 106/1280  step=530  tr_raw=1.1348  tr_amb=1.0655  va_raw=3.6758  va_amb=2.4102  tr_trace=13.16  va_trace=24.04  |g_data|=1.002e+01  |g_reg|=2.663e+01  |g_tot|=1.002e+01  t_prep=0.62ms  t_Ld=15.90ms  t_Lr=10.41ms  t_bwd=30.77ms  t_opt=4.76ms
# [raw|legacy] epoch 107/1280  step=535  tr_raw=1.0677  tr_amb=1.0016  va_raw=3.6491  va_amb=2.4334  tr_trace=12.43  va_trace=24.14  |g_data|=1.255e+01  |g_reg|=5.730e+01  |g_tot|=1.255e+01  t_prep=0.64ms  t_Ld=15.87ms  t_Lr=8.82ms  t_bwd=30.88ms  t_opt=4.91ms
# [raw|legacy] epoch 108/1280  step=540  tr_raw=0.9807  tr_amb=0.9280  va_raw=3.7356  va_amb=2.5043  tr_trace=11.49  va_trace=27.81  |g_data|=9.122e+00  |g_reg|=3.563e+01  |g_tot|=9.122e+00  t_prep=0.64ms  t_Ld=16.17ms  t_Lr=10.33ms  t_bwd=30.81ms  t_opt=5.10ms
# [raw|legacy] epoch 109/1280  step=545  tr_raw=1.0262  tr_amb=0.9554  va_raw=3.7208  va_amb=2.4453  tr_trace=11.93  va_trace=24.08  |g_data|=1.303e+01  |g_reg|=6.221e+01  |g_tot|=1.303e+01  t_prep=0.62ms  t_Ld=15.89ms  t_Lr=9.09ms  t_bwd=30.76ms  t_opt=4.76ms
# [raw|legacy] epoch 110/1280  step=550  tr_raw=1.0211  tr_amb=0.9610  va_raw=3.7227  va_amb=2.5382  tr_trace=12.20  va_trace=27.97  |g_data|=9.070e+00  |g_reg|=5.245e+01  |g_tot|=9.070e+00  t_prep=0.58ms  t_Ld=15.91ms  t_Lr=9.67ms  t_bwd=30.81ms  t_opt=4.70ms
# [raw|legacy] epoch 111/1280  step=555  tr_raw=0.9423  tr_amb=0.8882  va_raw=3.5977  va_amb=2.4083  tr_trace=10.85  va_trace=25.19  |g_data|=9.604e+00  |g_reg|=6.544e+01  |g_tot|=9.604e+00  t_prep=0.63ms  t_Ld=15.97ms  t_Lr=9.46ms  t_bwd=30.87ms  t_opt=4.73ms
# [raw|legacy] epoch 112/1280  step=560  tr_raw=1.0482  tr_amb=0.9819  va_raw=3.8008  va_amb=2.6395  tr_trace=11.61  va_trace=29.47  |g_data|=8.335e+00  |g_reg|=3.290e+01  |g_tot|=8.335e+00  t_prep=0.63ms  t_Ld=15.95ms  t_Lr=9.24ms  t_bwd=30.75ms  t_opt=4.73ms
# [raw|legacy] epoch 113/1280  step=565  tr_raw=0.9689  tr_amb=0.9112  va_raw=3.7649  va_amb=2.4696  tr_trace=10.95  va_trace=25.46  |g_data|=9.492e+00  |g_reg|=6.635e+01  |g_tot|=9.492e+00  t_prep=0.65ms  t_Ld=16.02ms  t_Lr=9.51ms  t_bwd=30.90ms  t_opt=4.69ms
# [raw|legacy] epoch 114/1280  step=570  tr_raw=1.0300  tr_amb=0.9839  va_raw=3.8670  va_amb=2.6576  tr_trace=13.57  va_trace=32.57  |g_data|=1.813e+01  |g_reg|=1.089e+02  |g_tot|=1.813e+01  t_prep=0.71ms  t_Ld=15.97ms  t_Lr=9.51ms  t_bwd=30.75ms  t_opt=4.74ms
# [raw|legacy] epoch 115/1280  step=575  tr_raw=0.9519  tr_amb=0.9005  va_raw=3.6975  va_amb=2.4388  tr_trace=12.59  va_trace=26.04  |g_data|=1.014e+01  |g_reg|=5.553e+01  |g_tot|=1.014e+01  t_prep=0.59ms  t_Ld=15.91ms  t_Lr=10.80ms  t_bwd=30.76ms  t_opt=4.68ms
# [raw|legacy] epoch 116/1280  step=580  tr_raw=0.9507  tr_amb=0.9001  va_raw=3.7211  va_amb=2.4441  tr_trace=11.97  va_trace=25.43  |g_data|=9.184e+00  |g_reg|=3.036e+01  |g_tot|=9.184e+00  t_prep=0.63ms  t_Ld=16.07ms  t_Lr=9.23ms  t_bwd=30.75ms  t_opt=4.87ms
# [raw|legacy] epoch 117/1280  step=585  tr_raw=0.8522  tr_amb=0.8148  va_raw=3.6756  va_amb=2.5719  tr_trace=10.26  va_trace=27.98  |g_data|=8.605e+00  |g_reg|=3.357e+01  |g_tot|=8.605e+00  t_prep=0.59ms  t_Ld=15.92ms  t_Lr=9.47ms  t_bwd=30.64ms  t_opt=4.73ms
# [raw|legacy] epoch 118/1280  step=590  tr_raw=0.8989  tr_amb=0.8518  va_raw=3.8302  va_amb=2.5977  tr_trace=10.90  va_trace=28.38  |g_data|=1.654e+01  |g_reg|=7.799e+01  |g_tot|=1.654e+01  t_prep=0.73ms  t_Ld=16.00ms  t_Lr=9.32ms  t_bwd=30.62ms  t_opt=4.78ms
# [raw|legacy] epoch 119/1280  step=595  tr_raw=0.9087  tr_amb=0.8604  va_raw=3.7546  va_amb=2.5555  tr_trace=12.19  va_trace=29.25  |g_data|=1.346e+01  |g_reg|=8.076e+01  |g_tot|=1.346e+01  t_prep=0.63ms  t_Ld=15.88ms  t_Lr=10.06ms  t_bwd=30.76ms  t_opt=4.73ms
# [raw|legacy] epoch 120/1280  step=600  tr_raw=0.8921  tr_amb=0.8503  va_raw=3.7113  va_amb=2.4023  tr_trace=11.73  va_trace=25.45  |g_data|=9.359e+00  |g_reg|=5.020e+01  |g_tot|=9.359e+00  t_prep=0.71ms  t_Ld=15.95ms  t_Lr=9.65ms  t_bwd=30.63ms  t_opt=4.73ms
# [raw|legacy] epoch 121/1280  step=605  tr_raw=0.8789  tr_amb=0.8370  va_raw=3.7441  va_amb=2.5028  tr_trace=10.55  va_trace=26.95  |g_data|=9.295e+00  |g_reg|=1.980e+01  |g_tot|=9.295e+00  t_prep=0.55ms  t_Ld=15.88ms  t_Lr=9.75ms  t_bwd=30.61ms  t_opt=4.78ms
# [raw|legacy] epoch 122/1280  step=610  tr_raw=1.0295  tr_amb=0.9690  va_raw=3.7267  va_amb=2.5998  tr_trace=12.02  va_trace=28.66  |g_data|=1.322e+01  |g_reg|=6.514e+01  |g_tot|=1.322e+01  t_prep=0.66ms  t_Ld=15.94ms  t_Lr=10.12ms  t_bwd=30.65ms  t_opt=4.69ms
# [raw|legacy] epoch 123/1280  step=615  tr_raw=0.8763  tr_amb=0.8329  va_raw=3.6094  va_amb=2.4317  tr_trace=10.98  va_trace=25.72  |g_data|=1.146e+01  |g_reg|=2.265e+01  |g_tot|=1.146e+01  t_prep=0.59ms  t_Ld=15.98ms  t_Lr=10.69ms  t_bwd=30.73ms  t_opt=4.83ms
# [raw|legacy] epoch 124/1280  step=620  tr_raw=0.9818  tr_amb=0.9297  va_raw=3.6575  va_amb=2.4144  tr_trace=11.95  va_trace=24.39  |g_data|=1.022e+01  |g_reg|=2.930e+01  |g_tot|=1.022e+01  t_prep=0.66ms  t_Ld=16.01ms  t_Lr=9.09ms  t_bwd=30.61ms  t_opt=4.75ms
# [raw|legacy] epoch 125/1280  step=625  tr_raw=0.8608  tr_amb=0.8182  va_raw=3.7489  va_amb=2.7116  tr_trace=10.16  va_trace=32.93  |g_data|=1.179e+01  |g_reg|=5.866e+01  |g_tot|=1.179e+01  t_prep=0.64ms  t_Ld=15.88ms  t_Lr=10.15ms  t_bwd=30.64ms  t_opt=4.73ms
# [raw|legacy] epoch 126/1280  step=630  tr_raw=0.8327  tr_amb=0.7978  va_raw=3.7247  va_amb=2.5054  tr_trace=9.68  va_trace=27.52  |g_data|=8.890e+00  |g_reg|=1.416e+01  |g_tot|=8.890e+00  t_prep=0.58ms  t_Ld=16.01ms  t_Lr=9.61ms  t_bwd=30.59ms  t_opt=4.81ms
# [raw|legacy] epoch 127/1280  step=635  tr_raw=0.8003  tr_amb=0.7656  va_raw=3.6947  va_amb=2.5011  tr_trace=9.34  va_trace=26.04  |g_data|=1.409e+01  |g_reg|=8.529e+01  |g_tot|=1.409e+01  t_prep=0.65ms  t_Ld=15.88ms  t_Lr=9.19ms  t_bwd=30.68ms  t_opt=4.69ms
# [raw|legacy] epoch 128/1280  step=640  tr_raw=0.8003  tr_amb=0.7654  va_raw=3.7540  va_amb=2.5347  tr_trace=9.79  va_trace=27.94  |g_data|=1.428e+01  |g_reg|=7.600e+01  |g_tot|=1.428e+01  t_prep=0.61ms  t_Ld=16.00ms  t_Lr=9.69ms  t_bwd=30.67ms  t_opt=4.67ms
# [raw|legacy] epoch 129/1280  step=645  tr_raw=0.7391  tr_amb=0.7109  va_raw=3.7087  va_amb=2.4788  tr_trace=9.10  va_trace=26.04  |g_data|=1.611e+01  |g_reg|=1.154e+02  |g_tot|=1.611e+01  t_prep=0.58ms  t_Ld=15.86ms  t_Lr=9.22ms  t_bwd=30.71ms  t_opt=4.84ms
# [raw|legacy] epoch 130/1280  step=650  tr_raw=0.8322  tr_amb=0.7894  va_raw=3.6947  va_amb=2.4398  tr_trace=10.48  va_trace=25.83  |g_data|=8.765e+00  |g_reg|=6.614e+01  |g_tot|=8.765e+00  t_prep=0.61ms  t_Ld=15.93ms  t_Lr=9.81ms  t_bwd=30.63ms  t_opt=4.75ms
# [raw|legacy] epoch 131/1280  step=655  tr_raw=0.7543  tr_amb=0.7218  va_raw=3.7825  va_amb=2.5568  tr_trace=9.93  va_trace=30.73  |g_data|=1.637e+01  |g_reg|=1.059e+02  |g_tot|=1.637e+01  t_prep=0.68ms  t_Ld=15.95ms  t_Lr=9.16ms  t_bwd=30.69ms  t_opt=4.88ms
# [raw|legacy] epoch 132/1280  step=660  tr_raw=0.8010  tr_amb=0.7611  va_raw=3.7928  va_amb=2.5700  tr_trace=10.89  va_trace=27.50  |g_data|=8.611e+00  |g_reg|=3.347e+01  |g_tot|=8.611e+00  t_prep=0.57ms  t_Ld=15.87ms  t_Lr=9.96ms  t_bwd=30.63ms  t_opt=4.71ms
# [raw|legacy] epoch 133/1280  step=665  tr_raw=0.7331  tr_amb=0.7102  va_raw=3.8130  va_amb=2.6592  tr_trace=9.72  va_trace=29.84  |g_data|=9.557e+00  |g_reg|=6.928e+01  |g_tot|=9.557e+00  t_prep=0.59ms  t_Ld=15.90ms  t_Lr=10.05ms  t_bwd=30.62ms  t_opt=4.81ms
# [raw|legacy] epoch 134/1280  step=670  tr_raw=0.7901  tr_amb=0.7555  va_raw=3.6360  va_amb=2.4875  tr_trace=10.13  va_trace=26.25  |g_data|=9.418e+00  |g_reg|=2.522e+01  |g_tot|=9.418e+00  t_prep=0.61ms  t_Ld=16.04ms  t_Lr=10.39ms  t_bwd=30.59ms  t_opt=4.71ms
# [raw|legacy] epoch 135/1280  step=675  tr_raw=0.7821  tr_amb=0.7526  va_raw=3.8429  va_amb=2.7776  tr_trace=10.14  va_trace=33.76  |g_data|=1.196e+01  |g_reg|=8.028e+01  |g_tot|=1.196e+01  t_prep=0.82ms  t_Ld=15.91ms  t_Lr=9.72ms  t_bwd=30.63ms  t_opt=4.86ms
# [raw|legacy] epoch 136/1280  step=680  tr_raw=0.7208  tr_amb=0.6882  va_raw=3.6405  va_amb=2.4367  tr_trace=9.07  va_trace=24.52  |g_data|=9.076e+00  |g_reg|=4.417e+01  |g_tot|=9.076e+00  t_prep=0.65ms  t_Ld=16.00ms  t_Lr=9.19ms  t_bwd=30.63ms  t_opt=4.71ms
# [raw|legacy] epoch 137/1280  step=685  tr_raw=0.7557  tr_amb=0.7228  va_raw=3.6799  va_amb=2.5145  tr_trace=9.49  va_trace=27.83  |g_data|=1.800e+01  |g_reg|=8.843e+01  |g_tot|=1.800e+01  t_prep=0.55ms  t_Ld=15.98ms  t_Lr=9.25ms  t_bwd=30.70ms  t_opt=4.72ms
# [raw|legacy] epoch 138/1280  step=690  tr_raw=0.6995  tr_amb=0.6710  va_raw=3.6089  va_amb=2.3572  tr_trace=8.26  va_trace=23.79  |g_data|=1.175e+01  |g_reg|=4.643e+01  |g_tot|=1.175e+01  t_prep=0.57ms  t_Ld=16.01ms  t_Lr=9.92ms  t_bwd=30.71ms  t_opt=4.74ms
# [raw|legacy] epoch 139/1280  step=695  tr_raw=0.6772  tr_amb=0.6531  va_raw=3.7272  va_amb=2.6813  tr_trace=8.67  va_trace=31.58  |g_data|=1.307e+01  |g_reg|=7.148e+01  |g_tot|=1.307e+01  t_prep=0.66ms  t_Ld=15.83ms  t_Lr=9.98ms  t_bwd=30.60ms  t_opt=4.74ms
# [raw|legacy] epoch 140/1280  step=700  tr_raw=0.6499  tr_amb=0.6307  va_raw=3.7039  va_amb=2.5303  tr_trace=7.62  va_trace=28.36  |g_data|=1.007e+01  |g_reg|=6.359e+01  |g_tot|=1.007e+01  t_prep=0.60ms  t_Ld=16.01ms  t_Lr=9.45ms  t_bwd=30.69ms  t_opt=4.82ms
# [raw|legacy] epoch 141/1280  step=705  tr_raw=0.6677  tr_amb=0.6462  va_raw=3.7646  va_amb=2.5273  tr_trace=8.50  va_trace=27.23  |g_data|=1.248e+01  |g_reg|=3.970e+01  |g_tot|=1.248e+01  t_prep=0.72ms  t_Ld=16.10ms  t_Lr=10.14ms  t_bwd=30.61ms  t_opt=4.82ms
# [raw|legacy] epoch 142/1280  step=710  tr_raw=0.7130  tr_amb=0.6846  va_raw=3.7001  va_amb=2.6468  tr_trace=8.94  va_trace=30.11  |g_data|=1.249e+01  |g_reg|=7.065e+01  |g_tot|=1.249e+01  t_prep=0.66ms  t_Ld=15.96ms  t_Lr=8.85ms  t_bwd=30.66ms  t_opt=4.73ms
# [raw|legacy] epoch 143/1280  step=715  tr_raw=0.6785  tr_amb=0.6571  va_raw=3.6725  va_amb=2.5200  tr_trace=8.71  va_trace=27.35  |g_data|=1.062e+01  |g_reg|=2.425e+01  |g_tot|=1.062e+01  t_prep=0.61ms  t_Ld=15.82ms  t_Lr=8.92ms  t_bwd=30.61ms  t_opt=4.87ms
# [raw|legacy] epoch 144/1280  step=720  tr_raw=0.7981  tr_amb=0.7664  va_raw=3.7261  va_amb=2.5342  tr_trace=11.04  va_trace=27.43  |g_data|=8.396e+00  |g_reg|=5.291e+01  |g_tot|=8.396e+00  t_prep=0.61ms  t_Ld=15.89ms  t_Lr=9.37ms  t_bwd=30.65ms  t_opt=4.75ms
# [raw|legacy] epoch 145/1280  step=725  tr_raw=0.7275  tr_amb=0.6965  va_raw=3.8411  va_amb=2.6924  tr_trace=8.93  va_trace=30.29  |g_data|=1.900e+01  |g_reg|=1.243e+02  |g_tot|=1.900e+01  t_prep=0.62ms  t_Ld=15.98ms  t_Lr=9.78ms  t_bwd=30.76ms  t_opt=4.84ms
# [raw|legacy] epoch 146/1280  step=730  tr_raw=0.6920  tr_amb=0.6643  va_raw=3.7901  va_amb=2.7344  tr_trace=9.45  va_trace=31.67  |g_data|=1.489e+01  |g_reg|=1.063e+02  |g_tot|=1.489e+01  t_prep=0.60ms  t_Ld=15.98ms  t_Lr=9.78ms  t_bwd=30.64ms  t_opt=4.85ms
# [raw|legacy] epoch 147/1280  step=735  tr_raw=0.7994  tr_amb=0.7662  va_raw=3.6748  va_amb=2.5920  tr_trace=12.21  va_trace=30.27  |g_data|=1.528e+01  |g_reg|=9.283e+01  |g_tot|=1.528e+01  t_prep=0.63ms  t_Ld=15.92ms  t_Lr=10.43ms  t_bwd=30.59ms  t_opt=4.82ms
# [raw|legacy] epoch 148/1280  step=740  tr_raw=0.7463  tr_amb=0.7203  va_raw=3.7277  va_amb=2.6772  tr_trace=10.55  va_trace=31.13  |g_data|=9.543e+00  |g_reg|=2.114e+01  |g_tot|=9.543e+00  t_prep=0.59ms  t_Ld=16.03ms  t_Lr=9.17ms  t_bwd=30.64ms  t_opt=5.03ms
# [raw|legacy] epoch 149/1280  step=745  tr_raw=0.6961  tr_amb=0.6712  va_raw=3.8579  va_amb=2.5372  tr_trace=9.20  va_trace=26.30  |g_data|=2.559e+01  |g_reg|=1.563e+02  |g_tot|=2.559e+01  t_prep=0.64ms  t_Ld=15.88ms  t_Lr=10.24ms  t_bwd=30.60ms  t_opt=4.82ms
# [raw|legacy] epoch 150/1280  step=750  tr_raw=0.7417  tr_amb=0.7262  va_raw=3.7870  va_amb=2.5201  tr_trace=11.82  va_trace=27.25  |g_data|=1.108e+01  |g_reg|=4.841e+01  |g_tot|=1.108e+01  t_prep=0.75ms  t_Ld=16.01ms  t_Lr=8.77ms  t_bwd=30.63ms  t_opt=4.76ms
# [raw|legacy] epoch 151/1280  step=755  tr_raw=0.7410  tr_amb=0.7093  va_raw=3.8014  va_amb=2.5545  tr_trace=9.41  va_trace=28.41  |g_data|=8.691e+00  |g_reg|=1.565e+01  |g_tot|=8.691e+00  t_prep=0.70ms  t_Ld=15.94ms  t_Lr=10.30ms  t_bwd=30.63ms  t_opt=4.74ms
# [raw|legacy] epoch 152/1280  step=760  tr_raw=0.6826  tr_amb=0.6601  va_raw=3.6904  va_amb=2.5088  tr_trace=9.18  va_trace=26.87  |g_data|=8.254e+00  |g_reg|=1.493e+01  |g_tot|=8.254e+00  t_prep=0.68ms  t_Ld=15.93ms  t_Lr=9.31ms  t_bwd=30.65ms  t_opt=4.82ms
# [raw|legacy] epoch 153/1280  step=765  tr_raw=0.6246  tr_amb=0.6065  va_raw=3.6601  va_amb=2.5587  tr_trace=8.24  va_trace=29.45  |g_data|=1.874e+01  |g_reg|=1.063e+02  |g_tot|=1.874e+01  t_prep=0.65ms  t_Ld=16.01ms  t_Lr=9.37ms  t_bwd=30.67ms  t_opt=4.86ms
# [raw|legacy] epoch 154/1280  step=770  tr_raw=0.7285  tr_amb=0.6993  va_raw=3.7081  va_amb=2.6718  tr_trace=9.55  va_trace=33.76  |g_data|=1.770e+01  |g_reg|=1.095e+02  |g_tot|=1.770e+01  t_prep=0.62ms  t_Ld=15.90ms  t_Lr=9.93ms  t_bwd=30.65ms  t_opt=4.76ms
# [raw|legacy] epoch 155/1280  step=775  tr_raw=0.6967  tr_amb=0.6663  va_raw=3.9197  va_amb=2.8150  tr_trace=9.48  va_trace=35.34  |g_data|=1.215e+01  |g_reg|=5.028e+01  |g_tot|=1.215e+01  t_prep=0.66ms  t_Ld=15.94ms  t_Lr=10.67ms  t_bwd=30.66ms  t_opt=4.81ms
# [raw|legacy] epoch 156/1280  step=780  tr_raw=0.7285  tr_amb=0.6978  va_raw=3.7745  va_amb=2.6453  tr_trace=10.05  va_trace=30.83  |g_data|=9.228e+00  |g_reg|=1.872e+01  |g_tot|=9.228e+00  t_prep=0.56ms  t_Ld=15.97ms  t_Lr=9.00ms  t_bwd=30.64ms  t_opt=4.74ms
# [raw|legacy] epoch 157/1280  step=785  tr_raw=0.6445  tr_amb=0.6291  va_raw=3.7586  va_amb=2.5646  tr_trace=8.85  va_trace=28.25  |g_data|=1.571e+01  |g_reg|=7.273e+01  |g_tot|=1.571e+01  t_prep=0.64ms  t_Ld=15.91ms  t_Lr=8.90ms  t_bwd=30.70ms  t_opt=4.69ms
# [raw|legacy] epoch 158/1280  step=790  tr_raw=0.6500  tr_amb=0.6286  va_raw=3.7340  va_amb=2.6210  tr_trace=8.27  va_trace=30.14  |g_data|=1.469e+01  |g_reg|=8.413e+01  |g_tot|=1.469e+01  t_prep=0.66ms  t_Ld=15.91ms  t_Lr=9.25ms  t_bwd=30.64ms  t_opt=4.84ms
# [raw|legacy] epoch 159/1280  step=795  tr_raw=0.5752  tr_amb=0.5553  va_raw=3.7093  va_amb=2.5243  tr_trace=7.75  va_trace=29.61  |g_data|=1.509e+01  |g_reg|=8.619e+01  |g_tot|=1.509e+01  t_prep=0.72ms  t_Ld=15.89ms  t_Lr=10.52ms  t_bwd=30.70ms  t_opt=4.85ms
# [raw|legacy] epoch 160/1280  step=800  tr_raw=0.5844  tr_amb=0.5621  va_raw=3.6582  va_amb=2.3925  tr_trace=8.13  va_trace=24.33  |g_data|=1.032e+01  |g_reg|=3.495e+01  |g_tot|=1.032e+01  t_prep=0.58ms  t_Ld=15.98ms  t_Lr=9.49ms  t_bwd=30.58ms  t_opt=4.94ms
# [raw|legacy] epoch 161/1280  step=805  tr_raw=0.5768  tr_amb=0.5583  va_raw=3.7651  va_amb=2.6255  tr_trace=7.94  va_trace=29.13  |g_data|=2.289e+01  |g_reg|=1.500e+02  |g_tot|=2.289e+01  t_prep=0.62ms  t_Ld=16.02ms  t_Lr=9.45ms  t_bwd=30.71ms  t_opt=4.81ms
# [raw|legacy] epoch 162/1280  step=810  tr_raw=0.6919  tr_amb=0.6703  va_raw=3.6311  va_amb=2.5039  tr_trace=10.63  va_trace=25.57  |g_data|=2.327e+01  |g_reg|=1.550e+02  |g_tot|=2.327e+01  t_prep=0.56ms  t_Ld=15.85ms  t_Lr=9.70ms  t_bwd=30.66ms  t_opt=4.84ms
# [raw|legacy] epoch 163/1280  step=815  tr_raw=0.6083  tr_amb=0.5890  va_raw=3.7350  va_amb=2.5063  tr_trace=9.90  va_trace=26.41  |g_data|=2.429e+01  |g_reg|=1.556e+02  |g_tot|=2.429e+01  t_prep=0.69ms  t_Ld=15.95ms  t_Lr=10.44ms  t_bwd=30.62ms  t_opt=4.84ms
# [raw|legacy] epoch 164/1280  step=820  tr_raw=0.5864  tr_amb=0.5713  va_raw=3.7839  va_amb=2.6003  tr_trace=9.07  va_trace=30.43  |g_data|=9.243e+00  |g_reg|=3.776e+01  |g_tot|=9.243e+00  t_prep=0.62ms  t_Ld=15.90ms  t_Lr=9.60ms  t_bwd=30.69ms  t_opt=4.77ms
# [raw|legacy] epoch 165/1280  step=825  tr_raw=0.6657  tr_amb=0.6409  va_raw=3.8435  va_amb=2.8269  tr_trace=9.55  va_trace=34.72  |g_data|=9.258e+00  |g_reg|=2.404e+01  |g_tot|=9.258e+00  t_prep=0.60ms  t_Ld=15.99ms  t_Lr=9.03ms  t_bwd=30.65ms  t_opt=4.86ms
# [raw|legacy] epoch 166/1280  step=830  tr_raw=0.6829  tr_amb=0.6577  va_raw=3.6864  va_amb=2.5761  tr_trace=9.87  va_trace=30.21  |g_data|=1.403e+01  |g_reg|=8.439e+01  |g_tot|=1.403e+01  t_prep=0.60ms  t_Ld=15.93ms  t_Lr=10.92ms  t_bwd=30.64ms  t_opt=4.84ms
# [raw|legacy] epoch 167/1280  step=835  tr_raw=0.6497  tr_amb=0.6292  va_raw=3.6884  va_amb=2.4069  tr_trace=9.55  va_trace=25.26  |g_data|=1.158e+01  |g_reg|=2.875e+01  |g_tot|=1.158e+01  t_prep=0.66ms  t_Ld=15.89ms  t_Lr=9.59ms  t_bwd=30.71ms  t_opt=4.87ms
# [raw|legacy] epoch 168/1280  step=840  tr_raw=0.7020  tr_amb=0.6739  va_raw=3.6044  va_amb=2.4997  tr_trace=9.48  va_trace=27.54  |g_data|=8.752e+00  |g_reg|=2.323e+01  |g_tot|=8.752e+00  t_prep=0.60ms  t_Ld=15.89ms  t_Lr=10.46ms  t_bwd=30.64ms  t_opt=4.72ms
# [raw|legacy] epoch 169/1280  step=845  tr_raw=0.5893  tr_amb=0.5703  va_raw=3.7527  va_amb=2.5492  tr_trace=7.77  va_trace=28.40  |g_data|=9.278e+00  |g_reg|=4.670e+01  |g_tot|=9.278e+00  t_prep=0.64ms  t_Ld=15.90ms  t_Lr=9.85ms  t_bwd=30.77ms  t_opt=4.72ms
# [raw|legacy] epoch 170/1280  step=850  tr_raw=0.5296  tr_amb=0.5122  va_raw=3.7411  va_amb=2.6404  tr_trace=6.78  va_trace=30.32  |g_data|=1.061e+01  |g_reg|=6.893e+01  |g_tot|=1.061e+01  t_prep=0.62ms  t_Ld=15.99ms  t_Lr=9.57ms  t_bwd=30.64ms  t_opt=5.01ms
# [raw|legacy] epoch 171/1280  step=855  tr_raw=0.6277  tr_amb=0.6105  va_raw=3.6537  va_amb=2.4952  tr_trace=8.20  va_trace=27.37  |g_data|=1.183e+01  |g_reg|=2.885e+01  |g_tot|=1.183e+01  t_prep=0.62ms  t_Ld=15.97ms  t_Lr=9.14ms  t_bwd=30.66ms  t_opt=4.77ms
# [raw|legacy] epoch 172/1280  step=860  tr_raw=0.5600  tr_amb=0.5467  va_raw=3.6052  va_amb=2.3965  tr_trace=7.69  va_trace=23.85  |g_data|=9.324e+00  |g_reg|=3.034e+01  |g_tot|=9.324e+00  t_prep=0.60ms  t_Ld=15.93ms  t_Lr=8.99ms  t_bwd=30.64ms  t_opt=4.72ms
# [raw|legacy] epoch 173/1280  step=865  tr_raw=0.6206  tr_amb=0.6002  va_raw=3.6902  va_amb=2.5096  tr_trace=8.61  va_trace=25.67  |g_data|=2.019e+01  |g_reg|=1.436e+02  |g_tot|=2.019e+01  t_prep=0.58ms  t_Ld=15.89ms  t_Lr=9.89ms  t_bwd=30.69ms  t_opt=4.73ms
# [raw|legacy] epoch 174/1280  step=870  tr_raw=0.5859  tr_amb=0.5726  va_raw=3.6523  va_amb=2.5460  tr_trace=8.97  va_trace=27.02  |g_data|=1.193e+01  |g_reg|=4.675e+01  |g_tot|=1.193e+01  t_prep=0.66ms  t_Ld=15.92ms  t_Lr=9.83ms  t_bwd=30.81ms  t_opt=4.87ms
# [raw|legacy] epoch 175/1280  step=875  tr_raw=0.5870  tr_amb=0.5746  va_raw=3.6385  va_amb=2.3856  tr_trace=7.66  va_trace=24.29  |g_data|=7.730e+00  |g_reg|=1.360e+01  |g_tot|=7.730e+00  t_prep=0.55ms  t_Ld=15.92ms  t_Lr=9.00ms  t_bwd=30.75ms  t_opt=4.78ms
# [raw|legacy] epoch 176/1280  step=880  tr_raw=0.5653  tr_amb=0.5493  va_raw=3.7096  va_amb=2.5069  tr_trace=7.55  va_trace=26.45  |g_data|=7.620e+00  |g_reg|=1.475e+01  |g_tot|=7.620e+00  t_prep=0.67ms  t_Ld=15.93ms  t_Lr=10.42ms  t_bwd=30.64ms  t_opt=4.91ms
# [raw|legacy] epoch 177/1280  step=885  tr_raw=0.6069  tr_amb=0.5845  va_raw=3.6872  va_amb=2.5686  tr_trace=8.80  va_trace=27.60  |g_data|=1.677e+01  |g_reg|=1.360e+02  |g_tot|=1.677e+01  t_prep=0.63ms  t_Ld=15.94ms  t_Lr=8.80ms  t_bwd=30.64ms  t_opt=4.72ms
# [raw|legacy] epoch 178/1280  step=890  tr_raw=0.5494  tr_amb=0.5340  va_raw=3.7976  va_amb=2.7675  tr_trace=8.30  va_trace=33.90  |g_data|=1.373e+01  |g_reg|=8.074e+01  |g_tot|=1.373e+01  t_prep=0.73ms  t_Ld=16.09ms  t_Lr=10.12ms  t_bwd=30.63ms  t_opt=4.81ms
# [raw|legacy] epoch 179/1280  step=895  tr_raw=0.6111  tr_amb=0.5928  va_raw=3.6521  va_amb=2.5122  tr_trace=8.46  va_trace=26.40  |g_data|=1.401e+01  |g_reg|=7.695e+01  |g_tot|=1.401e+01  t_prep=0.57ms  t_Ld=15.87ms  t_Lr=9.39ms  t_bwd=30.70ms  t_opt=4.68ms
# [raw|legacy] epoch 180/1280  step=900  tr_raw=0.5418  tr_amb=0.5290  va_raw=3.7450  va_amb=2.6326  tr_trace=7.24  va_trace=30.57  |g_data|=9.128e+00  |g_reg|=2.330e+01  |g_tot|=9.128e+00  t_prep=0.66ms  t_Ld=15.94ms  t_Lr=9.75ms  t_bwd=30.66ms  t_opt=4.74ms
# [raw|legacy] epoch 181/1280  step=905  tr_raw=0.5874  tr_amb=0.5663  va_raw=3.6217  va_amb=2.3983  tr_trace=8.13  va_trace=26.17  |g_data|=1.405e+01  |g_reg|=8.461e+01  |g_tot|=1.405e+01  t_prep=0.75ms  t_Ld=15.92ms  t_Lr=9.78ms  t_bwd=30.60ms  t_opt=4.73ms
# [raw|legacy] epoch 182/1280  step=910  tr_raw=0.5176  tr_amb=0.5049  va_raw=3.7791  va_amb=2.6458  tr_trace=7.82  va_trace=33.37  |g_data|=1.120e+01  |g_reg|=6.035e+01  |g_tot|=1.120e+01  t_prep=0.58ms  t_Ld=16.01ms  t_Lr=10.06ms  t_bwd=30.67ms  t_opt=4.92ms
# [raw|legacy] epoch 183/1280  step=915  tr_raw=0.4778  tr_amb=0.4702  va_raw=3.6384  va_amb=2.5344  tr_trace=6.55  va_trace=27.95  |g_data|=1.197e+01  |g_reg|=6.380e+01  |g_tot|=1.197e+01  t_prep=0.61ms  t_Ld=16.07ms  t_Lr=9.79ms  t_bwd=30.62ms  t_opt=4.73ms
# [raw|legacy] epoch 184/1280  step=920  tr_raw=0.5102  tr_amb=0.4975  va_raw=3.6392  va_amb=2.4141  tr_trace=6.89  va_trace=24.90  |g_data|=9.053e+00  |g_reg|=4.331e+01  |g_tot|=9.053e+00  t_prep=0.59ms  t_Ld=15.93ms  t_Lr=11.30ms  t_bwd=30.72ms  t_opt=4.91ms
# ...
# [raw|legacy] epoch 510/1280  step=2550  tr_raw=0.2831  tr_amb=0.2810  va_raw=3.4696  va_amb=2.3035  tr_trace=3.91  va_trace=24.02  |g_data|=7.429e+00  |g_reg|=2.822e+01  |g_tot|=7.429e+00  t_prep=0.65ms  t_Ld=16.01ms  t_Lr=9.97ms  t_bwd=30.70ms  t_opt=4.79ms
# [raw|legacy] epoch 511/1280  step=2555  tr_raw=0.2904  tr_amb=0.2833  va_raw=3.6908  va_amb=2.6439  tr_trace=3.76  va_trace=34.08  |g_data|=7.432e+00  |g_reg|=1.751e+01  |g_tot|=7.432e+00  t_prep=0.68ms  t_Ld=15.97ms  t_Lr=11.08ms  t_bwd=30.64ms  t_opt=4.84ms
# [raw|legacy] epoch 512/1280  step=2560  tr_raw=0.2737  tr_amb=0.2717  va_raw=3.4846  va_amb=2.2802  tr_trace=3.64  va_trace=23.86  |g_data|=7.327e+00  |g_reg|=2.403e+01  |g_tot|=7.327e+00  t_prep=0.63ms  t_Ld=15.92ms  t_Lr=9.82ms  t_bwd=30.64ms  t_opt=4.71ms
# [raw|legacy] epoch 513/1280  step=2565  tr_raw=0.2962  tr_amb=0.2915  va_raw=3.5097  va_amb=2.2917  tr_trace=3.90  va_trace=23.63  |g_data|=8.664e+00  |g_reg|=3.214e+01  |g_tot|=8.664e+00  t_prep=0.63ms  t_Ld=15.93ms  t_Lr=10.29ms  t_bwd=30.61ms  t_opt=4.73ms
# [raw|legacy] epoch 514/1280  step=2570  tr_raw=0.2519  tr_amb=0.2487  va_raw=3.6046  va_amb=2.4828  tr_trace=3.43  va_trace=28.25  |g_data|=1.056e+01  |g_reg|=6.623e+01  |g_tot|=1.056e+01  t_prep=0.62ms  t_Ld=16.06ms  t_Lr=9.65ms  t_bwd=30.66ms  t_opt=4.83ms
# [raw|legacy] epoch 515/1280  step=2575  tr_raw=0.3440  tr_amb=0.3360  va_raw=3.5986  va_amb=2.4436  tr_trace=4.71  va_trace=27.77  |g_data|=1.484e+01  |g_reg|=9.619e+01  |g_tot|=1.484e+01  t_prep=0.64ms  t_Ld=15.92ms  t_Lr=9.47ms  t_bwd=30.68ms  t_opt=4.90ms
# [raw|legacy] epoch 516/1280  step=2580  tr_raw=0.2721  tr_amb=0.2707  va_raw=3.5901  va_amb=2.4842  tr_trace=4.10  va_trace=29.28  |g_data|=8.082e+00  |g_reg|=1.773e+01  |g_tot|=8.082e+00  t_prep=0.67ms  t_Ld=15.89ms  t_Lr=9.76ms  t_bwd=30.63ms  t_opt=4.87ms
# [raw|legacy] epoch 517/1280  step=2585  tr_raw=0.2761  tr_amb=0.2740  va_raw=3.7431  va_amb=2.6766  tr_trace=4.25  va_trace=35.03  |g_data|=1.105e+01  |g_reg|=7.414e+01  |g_tot|=1.105e+01  t_prep=0.74ms  t_Ld=15.95ms  t_Lr=11.57ms  t_bwd=30.57ms  t_opt=4.79ms
# [raw|legacy] epoch 518/1280  step=2590  tr_raw=0.3109  tr_amb=0.3074  va_raw=3.6334  va_amb=2.6539  tr_trace=4.93  va_trace=33.88  |g_data|=1.343e+01  |g_reg|=4.036e+01  |g_tot|=1.343e+01  t_prep=0.63ms  t_Ld=15.90ms  t_Lr=10.27ms  t_bwd=30.76ms  t_opt=4.81ms
# [raw|legacy] epoch 519/1280  step=2595  tr_raw=0.3095  tr_amb=0.3063  va_raw=3.8318  va_amb=2.8653  tr_trace=4.42  va_trace=39.83  |g_data|=7.724e+00  |g_reg|=3.002e+01  |g_tot|=7.724e+00  t_prep=0.56ms  t_Ld=15.84ms  t_Lr=10.31ms  t_bwd=30.71ms  t_opt=4.77ms
# [raw|legacy] epoch 520/1280  step=2600  tr_raw=0.3644  tr_amb=0.3594  va_raw=3.6239  va_amb=2.4429  tr_trace=5.20  va_trace=28.01  |g_data|=8.001e+00  |g_reg|=2.366e+01  |g_tot|=8.001e+00  t_prep=0.73ms  t_Ld=15.96ms  t_Lr=10.15ms  t_bwd=30.68ms  t_opt=4.69ms
# [raw|legacy] epoch 521/1280  step=2605  tr_raw=0.3563  tr_amb=0.3494  va_raw=3.5019  va_amb=2.2860  tr_trace=4.98  va_trace=23.00  |g_data|=9.311e+00  |g_reg|=4.004e+01  |g_tot|=9.311e+00  t_prep=0.61ms  t_Ld=15.93ms  t_Lr=9.66ms  t_bwd=30.63ms  t_opt=4.99ms
# [raw|legacy] epoch 522/1280  step=2610  tr_raw=0.2869  tr_amb=0.2829  va_raw=3.6449  va_amb=2.4754  tr_trace=4.05  va_trace=28.58  |g_data|=1.388e+01  |g_reg|=7.052e+01  |g_tot|=1.388e+01  t_prep=0.62ms  t_Ld=15.94ms  t_Lr=10.10ms  t_bwd=30.56ms  t_opt=4.69ms
# [raw|legacy] epoch 523/1280  step=2615  tr_raw=0.2953  tr_amb=0.2921  va_raw=3.5090  va_amb=2.3008  tr_trace=4.02  va_trace=24.01  |g_data|=7.600e+00  |g_reg|=1.489e+01  |g_tot|=7.600e+00  t_prep=0.61ms  t_Ld=15.90ms  t_Lr=9.86ms  t_bwd=30.56ms  t_opt=4.74ms
# [raw|legacy] epoch 524/1280  step=2620  tr_raw=0.2715  tr_amb=0.2691  va_raw=3.5568  va_amb=2.4350  tr_trace=3.79  va_trace=28.72  |g_data|=1.225e+01  |g_reg|=4.512e+01  |g_tot|=1.225e+01  t_prep=0.64ms  t_Ld=15.91ms  t_Lr=9.70ms  t_bwd=30.72ms  t_opt=4.87ms
# [raw|legacy] epoch 525/1280  step=2625  tr_raw=0.2727  tr_amb=0.2701  va_raw=3.5077  va_amb=2.3316  tr_trace=3.79  va_trace=24.69  |g_data|=8.448e+00  |g_reg|=1.672e+01  |g_tot|=8.448e+00  t_prep=0.62ms  t_Ld=15.89ms  t_Lr=10.12ms  t_bwd=30.60ms  t_opt=4.76ms
# [raw|legacy] epoch 526/1280  step=2630  tr_raw=0.2814  tr_amb=0.2769  va_raw=3.6358  va_amb=2.6373  tr_trace=3.83  va_trace=33.20  |g_data|=1.035e+01  |g_reg|=2.670e+01  |g_tot|=1.035e+01  t_prep=0.58ms  t_Ld=16.03ms  t_Lr=8.87ms  t_bwd=30.61ms  t_opt=4.78ms
# [raw|legacy] epoch 527/1280  step=2635  tr_raw=0.3159  tr_amb=0.3107  va_raw=3.5056  va_amb=2.2891  tr_trace=4.26  va_trace=23.95  |g_data|=1.249e+01  |g_reg|=3.830e+01  |g_tot|=1.249e+01  t_prep=0.69ms  t_Ld=16.07ms  t_Lr=9.46ms  t_bwd=30.64ms  t_opt=4.85ms
# [raw|legacy] epoch 528/1280  step=2640  tr_raw=0.2744  tr_amb=0.2735  va_raw=3.4947  va_amb=2.2993  tr_trace=3.91  va_trace=23.67  |g_data|=7.938e+00  |g_reg|=2.046e+01  |g_tot|=7.938e+00  t_prep=0.57ms  t_Ld=16.00ms  t_Lr=10.35ms  t_bwd=30.68ms  t_opt=4.76ms
# [raw|legacy] epoch 529/1280  step=2645  tr_raw=0.2739  tr_amb=0.2733  va_raw=3.7214  va_amb=2.7599  tr_trace=3.63  va_trace=37.27  |g_data|=1.200e+01  |g_reg|=5.753e+01  |g_tot|=1.200e+01  t_prep=0.65ms  t_Ld=15.88ms  t_Lr=9.66ms  t_bwd=30.62ms  t_opt=4.82ms
# [raw|legacy] epoch 530/1280  step=2650  tr_raw=0.3146  tr_amb=0.3111  va_raw=3.6235  va_amb=2.4927  tr_trace=4.74  va_trace=29.51  |g_data|=1.166e+01  |g_reg|=5.853e+01  |g_tot|=1.166e+01  t_prep=0.56ms  t_Ld=15.89ms  t_Lr=10.31ms  t_bwd=30.59ms  t_opt=4.76ms
# [raw|legacy] epoch 531/1280  step=2655  tr_raw=0.3028  tr_amb=0.2987  va_raw=3.7912  va_amb=2.8634  tr_trace=5.27  va_trace=39.92  |g_data|=1.360e+01  |g_reg|=6.344e+01  |g_tot|=1.360e+01  t_prep=0.58ms  t_Ld=16.09ms  t_Lr=9.39ms  t_bwd=30.71ms  t_opt=4.71ms
# [raw|legacy] epoch 532/1280  step=2660  tr_raw=0.3195  tr_amb=0.3129  va_raw=3.5823  va_amb=2.4638  tr_trace=4.61  va_trace=27.76  |g_data|=1.923e+01  |g_reg|=1.092e+02  |g_tot|=1.923e+01  t_prep=0.61ms  t_Ld=15.97ms  t_Lr=10.54ms  t_bwd=30.66ms  t_opt=4.81ms
# [raw|legacy] epoch 533/1280  step=2665  tr_raw=0.3147  tr_amb=0.3124  va_raw=3.6643  va_amb=2.4675  tr_trace=5.44  va_trace=29.07  |g_data|=8.876e+00  |g_reg|=1.952e+01  |g_tot|=8.876e+00  t_prep=0.55ms  t_Ld=15.85ms  t_Lr=9.66ms  t_bwd=30.62ms  t_opt=4.71ms
# [raw|legacy] epoch 534/1280  step=2670  tr_raw=0.3490  tr_amb=0.3416  va_raw=3.6507  va_amb=2.6184  tr_trace=5.37  va_trace=34.30  |g_data|=8.698e+00  |g_reg|=6.127e+01  |g_tot|=8.698e+00  t_prep=0.71ms  t_Ld=15.95ms  t_Lr=10.14ms  t_bwd=30.59ms  t_opt=4.81ms
# [raw|legacy] epoch 535/1280  step=2675  tr_raw=0.3699  tr_amb=0.3605  va_raw=3.6497  va_amb=2.5064  tr_trace=5.01  va_trace=29.60  |g_data|=6.957e+00  |g_reg|=2.317e+01  |g_tot|=6.957e+00  t_prep=0.62ms  t_Ld=15.93ms  t_Lr=9.29ms  t_bwd=30.61ms  t_opt=4.74ms
# [raw|legacy] epoch 536/1280  step=2680  tr_raw=0.3106  tr_amb=0.3077  va_raw=3.5285  va_amb=2.3238  tr_trace=4.52  va_trace=23.71  |g_data|=1.548e+01  |g_reg|=7.290e+01  |g_tot|=1.548e+01  t_prep=0.57ms  t_Ld=16.04ms  t_Lr=9.76ms  t_bwd=30.61ms  t_opt=4.75ms
# [raw|legacy] epoch 537/1280  step=2685  tr_raw=0.3407  tr_amb=0.3352  va_raw=3.5680  va_amb=2.4228  tr_trace=4.68  va_trace=28.44  |g_data|=9.261e+00  |g_reg|=2.062e+01  |g_tot|=9.261e+00  t_prep=0.68ms  t_Ld=15.88ms  t_Lr=10.03ms  t_bwd=30.67ms  t_opt=5.11ms
# [raw|legacy] epoch 538/1280  step=2690  tr_raw=0.3504  tr_amb=0.3404  va_raw=3.5146  va_amb=2.3000  tr_trace=4.77  va_trace=23.22  |g_data|=1.414e+01  |g_reg|=7.709e+01  |g_tot|=1.414e+01  t_prep=0.69ms  t_Ld=15.88ms  t_Lr=9.69ms  t_bwd=30.65ms  t_opt=4.78ms
# [raw|legacy] epoch 539/1280  step=2695  tr_raw=0.2924  tr_amb=0.2904  va_raw=3.4844  va_amb=2.2912  tr_trace=4.15  va_trace=23.43  |g_data|=1.100e+01  |g_reg|=7.080e+01  |g_tot|=1.100e+01  t_prep=0.75ms  t_Ld=15.99ms  t_Lr=9.93ms  t_bwd=30.59ms  t_opt=4.97ms
# [raw|legacy] epoch 540/1280  step=2700  tr_raw=0.2882  tr_amb=0.2864  va_raw=3.5147  va_amb=2.4330  tr_trace=4.21  va_trace=28.60  |g_data|=9.147e+00  |g_reg|=2.426e+01  |g_tot|=9.147e+00  t_prep=0.67ms  t_Ld=15.95ms  t_Lr=10.83ms  t_bwd=30.62ms  t_opt=4.88ms
# [raw|legacy] epoch 541/1280  step=2705  tr_raw=0.2636  tr_amb=0.2602  va_raw=3.4952  va_amb=2.5006  tr_trace=3.59  va_trace=30.03  |g_data|=8.854e+00  |g_reg|=5.935e+01  |g_tot|=8.854e+00  t_prep=0.66ms  t_Ld=15.98ms  t_Lr=10.22ms  t_bwd=30.61ms  t_opt=4.70ms
# [raw|legacy] epoch 542/1280  step=2710  tr_raw=0.2980  tr_amb=0.2953  va_raw=3.5168  va_amb=2.2952  tr_trace=4.35  va_trace=23.94  |g_data|=8.488e+00  |g_reg|=1.902e+01  |g_tot|=8.488e+00  t_prep=0.65ms  t_Ld=15.97ms  t_Lr=9.46ms  t_bwd=30.62ms  t_opt=4.77ms
# [raw|legacy] epoch 543/1280  step=2715  tr_raw=0.2790  tr_amb=0.2758  va_raw=3.5799  va_amb=2.4265  tr_trace=3.80  va_trace=27.70  |g_data|=1.094e+01  |g_reg|=6.509e+01  |g_tot|=1.094e+01  t_prep=0.59ms  t_Ld=15.96ms  t_Lr=9.96ms  t_bwd=30.62ms  t_opt=4.79ms
# [raw|legacy] epoch 544/1280  step=2720  tr_raw=0.2821  tr_amb=0.2798  va_raw=3.5633  va_amb=2.5676  tr_trace=4.07  va_trace=32.11  |g_data|=1.155e+01  |g_reg|=3.249e+01  |g_tot|=1.155e+01  t_prep=0.63ms  t_Ld=15.92ms  t_Lr=9.57ms  t_bwd=30.56ms  t_opt=4.73ms
# [raw|legacy] epoch 545/1280  step=2725  tr_raw=0.2857  tr_amb=0.2811  va_raw=3.4772  va_amb=2.2902  tr_trace=4.01  va_trace=24.45  |g_data|=8.118e+00  |g_reg|=4.495e+01  |g_tot|=8.118e+00  t_prep=0.57ms  t_Ld=15.99ms  t_Lr=10.16ms  t_bwd=30.71ms  t_opt=4.86ms
# [raw|legacy] epoch 546/1280  step=2730  tr_raw=0.2541  tr_amb=0.2526  va_raw=3.6206  va_amb=2.6365  tr_trace=3.55  va_trace=33.57  |g_data|=7.557e+00  |g_reg|=2.331e+01  |g_tot|=7.557e+00  t_prep=0.60ms  t_Ld=16.00ms  t_Lr=9.99ms  t_bwd=30.60ms  t_opt=4.84ms
# [raw|legacy] epoch 547/1280  step=2735  tr_raw=0.2871  tr_amb=0.2853  va_raw=3.4809  va_amb=2.4306  tr_trace=4.25  va_trace=27.54  |g_data|=8.509e+00  |g_reg|=3.438e+01  |g_tot|=8.509e+00  t_prep=0.58ms  t_Ld=15.93ms  t_Lr=9.70ms  t_bwd=30.60ms  t_opt=4.78ms
# [raw|legacy] epoch 548/1280  step=2740  tr_raw=0.2463  tr_amb=0.2455  va_raw=3.4874  va_amb=2.2777  tr_trace=3.41  va_trace=23.04  |g_data|=8.964e+00  |g_reg|=1.843e+01  |g_tot|=8.964e+00  t_prep=0.59ms  t_Ld=15.92ms  t_Lr=9.57ms  t_bwd=30.68ms  t_opt=4.91ms
# [raw|legacy] epoch 549/1280  step=2745  tr_raw=0.2430  tr_amb=0.2420  va_raw=3.6936  va_amb=2.6396  tr_trace=3.40  va_trace=33.32  |g_data|=1.093e+01  |g_reg|=5.260e+01  |g_tot|=1.093e+01  t_prep=0.69ms  t_Ld=15.92ms  t_Lr=9.72ms  t_bwd=30.59ms  t_opt=4.78ms
# [raw|legacy] epoch 550/1280  step=2750  tr_raw=0.2688  tr_amb=0.2659  va_raw=3.4777  va_amb=2.2966  tr_trace=3.80  va_trace=24.13  |g_data|=1.404e+01  |g_reg|=8.215e+01  |g_tot|=1.404e+01  t_prep=0.56ms  t_Ld=16.00ms  t_Lr=10.18ms  t_bwd=30.55ms  t_opt=4.77ms
# [raw|legacy] epoch 551/1280  step=2755  tr_raw=0.2629  tr_amb=0.2624  va_raw=3.4783  va_amb=2.3122  tr_trace=4.04  va_trace=24.58  |g_data|=1.387e+01  |g_reg|=7.655e+01  |g_tot|=1.387e+01  t_prep=0.69ms  t_Ld=15.98ms  t_Lr=9.43ms  t_bwd=30.72ms  t_opt=4.82ms
# [raw|legacy] epoch 552/1280  step=2760  tr_raw=0.2432  tr_amb=0.2431  va_raw=3.5883  va_amb=2.4642  tr_trace=3.67  va_trace=28.27  |g_data|=8.669e+00  |g_reg|=1.225e+01  |g_tot|=8.669e+00  t_prep=0.66ms  t_Ld=15.97ms  t_Lr=10.02ms  t_bwd=30.59ms  t_opt=4.69ms
# [raw|legacy] epoch 553/1280  step=2765  tr_raw=0.2312  tr_amb=0.2305  va_raw=3.4813  va_amb=2.2784  tr_trace=3.13  va_trace=23.37  |g_data|=8.567e+00  |g_reg|=3.608e+01  |g_tot|=8.567e+00  t_prep=0.61ms  t_Ld=16.28ms  t_Lr=9.73ms  t_bwd=30.69ms  t_opt=4.83ms
# [raw|legacy] epoch 554/1280  step=2770  tr_raw=0.2652  tr_amb=0.2636  va_raw=3.6559  va_amb=2.4627  tr_trace=3.79  va_trace=28.23  |g_data|=1.406e+01  |g_reg|=7.352e+01  |g_tot|=1.406e+01  t_prep=0.61ms  t_Ld=15.94ms  t_Lr=10.13ms  t_bwd=30.61ms  t_opt=4.83ms
# [raw|legacy] epoch 555/1280  step=2775  tr_raw=0.2412  tr_amb=0.2400  va_raw=3.6795  va_amb=2.6705  tr_trace=3.73  va_trace=33.80  |g_data|=1.263e+01  |g_reg|=5.549e+01  |g_tot|=1.263e+01  t_prep=0.60ms  t_Ld=15.91ms  t_Lr=9.80ms  t_bwd=30.68ms  t_opt=4.79ms
# [raw|legacy] epoch 556/1280  step=2780  tr_raw=0.2366  tr_amb=0.2351  va_raw=3.5765  va_amb=2.4213  tr_trace=3.39  va_trace=27.82  |g_data|=9.093e+00  |g_reg|=1.577e+01  |g_tot|=9.093e+00  t_prep=0.59ms  t_Ld=15.93ms  t_Lr=10.87ms  t_bwd=30.73ms  t_opt=4.81ms
# [raw|legacy] epoch 557/1280  step=2785  tr_raw=0.2479  tr_amb=0.2465  va_raw=3.5156  va_amb=2.4678  tr_trace=3.30  va_trace=28.17  |g_data|=7.398e+00  |g_reg|=1.440e+01  |g_tot|=7.398e+00  t_prep=0.65ms  t_Ld=15.98ms  t_Lr=9.40ms  t_bwd=30.69ms  t_opt=4.77ms
# [raw|legacy] epoch 558/1280  step=2790  tr_raw=0.2334  tr_amb=0.2324  va_raw=3.5787  va_amb=2.5857  tr_trace=3.44  va_trace=32.97  |g_data|=7.860e+00  |g_reg|=3.509e+01  |g_tot|=7.860e+00  t_prep=0.68ms  t_Ld=15.96ms  t_Lr=9.43ms  t_bwd=30.59ms  t_opt=4.89ms
# [raw|legacy] epoch 559/1280  step=2795  tr_raw=0.3105  tr_amb=0.3070  va_raw=3.6369  va_amb=2.6380  tr_trace=4.83  va_trace=34.54  |g_data|=1.795e+01  |g_reg|=9.315e+01  |g_tot|=1.795e+01  t_prep=0.72ms  t_Ld=15.91ms  t_Lr=9.95ms  t_bwd=30.60ms  t_opt=4.78ms
# [raw|legacy] epoch 560/1280  step=2800  tr_raw=0.2651  tr_amb=0.2636  va_raw=3.5912  va_amb=2.4744  tr_trace=4.72  va_trace=29.40  |g_data|=1.176e+01  |g_reg|=5.247e+01  |g_tot|=1.176e+01  t_prep=0.60ms  t_Ld=15.88ms  t_Lr=10.73ms  t_bwd=30.65ms  t_opt=4.71ms
# [raw|legacy] epoch 561/1280  step=2805  tr_raw=0.3166  tr_amb=0.3128  va_raw=3.5840  va_amb=2.6176  tr_trace=4.87  va_trace=32.72  |g_data|=8.998e+00  |g_reg|=3.996e+01  |g_tot|=8.998e+00  t_prep=0.64ms  t_Ld=15.90ms  t_Lr=10.02ms  t_bwd=30.72ms  t_opt=4.83ms
# [raw|legacy] epoch 562/1280  step=2810  tr_raw=0.2643  tr_amb=0.2632  va_raw=3.4938  va_amb=2.3014  tr_trace=3.98  va_trace=23.34  |g_data|=9.951e+00  |g_reg|=6.509e+01  |g_tot|=9.951e+00  t_prep=0.68ms  t_Ld=15.94ms  t_Lr=10.73ms  t_bwd=30.76ms  t_opt=4.79ms
# [raw|legacy] early stop at epoch 562 (step=2810), best epoch 402 (best_step=2010), rule=steps(patience=800)
# {
#   "best_epoch": 402,
#   "best_score": 2.2696402046084403,
#   "stopped_epoch": 562,
#   "lam": 0.0,
#   "trace_scale": 8.174035226084497,
#   "pulse_loss_mode": "raw",
#   "ambiguity_backend": "legacy",
#   "trace_loss_ref": "clean",
#   "device": "cuda",
#   "train_snr_db_range": [
#     0.0,
#     30.0
#   ],
#   "train_snr_db_values": null,
#   "val_snr_db_range": [
#     -10.0,
#     30.0
#   ],
#   "val_snr_db_values": [
#     -10.0,
#     0.0,
#     30.0
#   ],
#   "n_train": 300,
#   "n_val": 200,
#   "seed": 0,
#   "loader_builder": "filtered_c1",
#   "canonicalize_mode": "t0",
#   "lr": 0.001,
#   "batch_size": 64,
#   "max_steps": 6400,
#   "global_step": 2810,
#   "best_step": 2010,
#   "early_stop_mode": "steps",
#   "early_stop_frac": 0.9,
#   "patience": 800,
#   "wall_time_data_sec": 9.024100499926135,
#   "wall_time_train_sec": 1090.215432099998,
#   "role": "plain_official",
#   "protocol": "v2",
#   "val_snr_policy": "discrete_{-10,0,30}",
#   "wall_time_total_sec": 1101.0555968999397
# }
# {
#   "best_epoch": 402,
#   "best_score": 2.2696402046084403,
#   "stopped_epoch": 562,
#   "lam": 0.0,
#   "trace_scale": 8.174035226084497,
#   "pulse_loss_mode": "raw",
#   "ambiguity_backend": "legacy",
#   "trace_loss_ref": "clean",
#   "device": "cuda",
#   "train_snr_db_range": [
#     0.0,
#     30.0
#   ],
#   "train_snr_db_values": null,
#   "val_snr_db_range": [
#     -10.0,
#     30.0
#   ],
#   "val_snr_db_values": [
#     -10.0,
#     0.0,
#     30.0
#   ],
#   "n_train": 300,
#   "n_val": 200,
#   "seed": 0,
#   "loader_builder": "filtered_c1",
#   "canonicalize_mode": "t0",
#   "lr": 0.001,
#   "batch_size": 64,
#   "max_steps": 6400,
#   "global_step": 2810,
#   "best_step": 2010,
#   "early_stop_mode": "steps",
#   "early_stop_frac": 0.9,
#   "patience": 800,
#   "wall_time_data_sec": 9.024100499926135,
#   "wall_time_train_sec": 1090.215432099998,
#   "role": "plain_official",
#   "protocol": "v2",
#   "val_snr_policy": "discrete_{-10,0,30}",
#   "wall_time_total_sec": 1101.0555968999397
# }
# best_step=2010  best_epoch=402  global_step=2810  max_steps=6400  stopped_epoch=562

# %% [markdown]
# ## Training curves (pulse / TRACE / gradients / timings)

# %%
plot_pulse_curves(hist, f"Plain v2 n={N_TRAIN} Î»=0 LR={LR:g}")
plot_trace_curves(hist, f"Plain v2 n={N_TRAIN} Î»=0 LR={LR:g}")
plot_grad_norms(hist, f"Plain v2 n={N_TRAIN} Î»=0 LR={LR:g}", lam=0.0)
summarize_timings(hist, f"Plain v2 n={N_TRAIN}")
print(
    f"wall_time_data_sec={meta.get('wall_time_data_sec')}  "
    f"wall_time_train_sec={meta.get('wall_time_train_sec')}  "
    f"global_step={meta.get('global_step')}"
)
# Out:
# === Plain v2 n=300: meanÂ±std over epochs (ms/batch) ===
#   data_prep_sec             0.642 Â±  0.064
#   loss_data_fwd_sec        15.981 Â±  0.166
#   loss_reg_fwd_sec          9.992 Â±  0.662
#   total_backward_sec       30.806 Â±  1.958
#   optimizer_step_sec        4.844 Â±  0.276
# wall_time_data_sec=9.024100499926135  wall_time_train_sec=1090.215432099998  global_step=2810

# %% [markdown]
# ## Snapshot evolution (val sample @ SNR=10 dB, every 2 epochs)

# %%
snap_path = OUT / f"{TAG}_snapshots.npz"
assert snap_path.exists(), snap_path
snap = np.load(snap_path)
epochs = snap["epoch"]
E_pred_all = snap["E_pred"]
if E_pred_all.ndim == 3:
    E_pred_all = E_pred_all[:, 0, :]
E_true = snap["E_true"]
if E_true.ndim == 3:
    E_true = E_true[0]
elif E_true.ndim == 2 and E_true.shape[0] == 1:
    E_true = E_true[0]
I_noisy = snap["I_noisy"]
if I_noisy.ndim == 4:
    I_noisy = I_noisy[0, 0]
elif I_noisy.ndim == 3:
    I_noisy = I_noisy[0]

pulse_cfg = filtered_c1_pulse_config(n=64)
dt = float(pulse_cfg.dt)
t_axis = np.linspace(-pulse_cfg.t_total_fs / 2.0, pulse_cfg.t_total_fs / 2.0, pulse_cfg.n)
e_true = unpack_packed_field(E_true)
I_show, tau_axis, omega_plot = prepare_frog_trace_for_plot(
    I_noisy, num_points=pulse_cfg.n, dt=dt
)
energy_ev = omega_plot * 4.135667696 / (2.0 * np.pi)
extent = [tau_axis[0], tau_axis[-1], energy_ev[0], energy_ev[-1]]

n_show = min(6, len(epochs))
show_idx = np.unique(np.linspace(0, len(epochs) - 1, n_show, dtype=int)).tolist()
fig, axes = plt.subplots(len(show_idx), 3, figsize=(12, 3.0 * len(show_idx)))
if len(show_idx) == 1:
    axes = np.array([axes])
for row, si in enumerate(show_idx):
    e_pred = unpack_packed_field(E_pred_all[si])
    e_al = best_l1_ambiguity_field(e_pred, e_true)
    amp_p, amp_t = np.abs(e_al), np.abs(e_true)
    ph_t, ph_p = unwrap_phases_for_overlay(e_al, e_true)
    axes[row, 0].imshow(
        I_show, aspect="auto", origin="lower", extent=extent, cmap="magma"
    )
    axes[row, 0].set_title(f"noisy TRACE  ep={int(epochs[si])}")
    axes[row, 0].set_xlabel("Delay Ï„ [fs]")
    axes[row, 0].set_ylabel("Relative energy [eV]")
    axes[row, 1].plot(t_axis, amp_t, label="true")
    axes[row, 1].plot(t_axis, amp_p, label="pred")
    axes[row, 1].set_title("|E(t)|")
    axes[row, 1].set_xlabel("Time [fs]")
    axes[row, 1].set_ylabel("|E| [a.u.]")
    axes[row, 1].legend(fontsize=8)
    axes[row, 2].plot(t_axis, ph_t, label="true")
    axes[row, 2].plot(t_axis, ph_p, label="pred")
    axes[row, 2].set_title("phase")
    axes[row, 2].set_xlabel("Time [fs]")
    axes[row, 2].set_ylabel("phase [rad]")
    axes[row, 2].legend(fontsize=8)
plt.suptitle(f"Plain v2 n={N_TRAIN} snapshot evolution @ SNR={SNAPSHOT_SNR_DB:g} dB")
plt.tight_layout()
plt.show()

l1s, sims = [], []
for i in range(len(epochs)):
    e_pred = unpack_packed_field(E_pred_all[i])
    l1s.append(best_l1_ambiguity(e_pred, e_true))
    sims.append(best_similarity_error_ambiguity(e_pred, e_true))
fig, ax = plt.subplots(figsize=(7, 3.5))
ax.plot(epochs, l1s, color="C0")
ax.set_xlabel("epoch")
ax.set_ylabel("L1 (best-amb)")
ax.set_title("Fixed val sample: L1_amb vs training epoch")
ax.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()
fig, ax = plt.subplots(figsize=(7, 3.5))
ax.plot(epochs, sims, color="C1")
ax.set_xlabel("epoch")
ax.set_ylabel("similarity error (best-amb)")
ax.set_title("Fixed val sample: SIM_amb vs training epoch")
ax.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Held-out test SNR sweep

# %%
bundle = build_filtered_c1_frog_dataloaders(
    n_train=max(N_TRAIN, 64),
    n_val=N_VAL,
    n_test=N_TEST,
    batch_size=BATCH_SIZE,
    seed=SEED,
    device=DEVICE,
    grid=filtered_c1_pulse_config(n=64),
    canonicalize_mode="t0",
)
test_loader = bundle.test_loader

sweep_path = OUT / f"{TAG}_test_snr_sweep.npz"
if FORCE_TEST_SWEEP or not sweep_path.exists():
    print("Running test SNR sweep...")
    diag.run_and_save_test_snr_sweep(
        OUT / f"{TAG}_model.pt",
        sweep_path,
        test_loader=test_loader,
        snr_sweep_db=SNR_SWEEP_DB,
        device=DEVICE,
        experiment_name=f"Plain v2 n={N_TRAIN} LR={LR:g}",
    )
else:
    print("skip sweep; using", sweep_path)

sweep = load_cnn_sweep(sweep_path)
fig, axes = plt.subplots(1, 2, figsize=(11, 4))
axes[0].errorbar(
    sweep.snr_sweep_db, sweep.cnn_l1_amb_m, yerr=sweep.cnn_l1_amb_s, marker="o"
)
axes[0].set_xlabel("SNR (dB)")
axes[0].set_ylabel("pulse L1 (best-amb)")
axes[0].set_title(f"Plain v2 n={N_TRAIN}: test L1 vs SNR")
axes[0].grid(True, alpha=0.3)
axes[1].errorbar(
    sweep.snr_sweep_db, sweep.cnn_sim_amb_m, yerr=sweep.cnn_sim_amb_s, marker="o"
)
axes[1].set_xlabel("SNR (dB)")
axes[1].set_ylabel("SIM error (best-amb)")
axes[1].set_title(f"Plain v2 n={N_TRAIN}: test SIM vs SNR")
axes[1].grid(True, alpha=0.3)
plt.tight_layout()
plt.show()
for snr, l1, sim in zip(sweep.snr_sweep_db, sweep.cnn_l1_amb_m, sweep.cnn_sim_amb_m):
    print(f"  SNR={snr:6.1f}  L1_amb={l1:.4f}  SIM_amb={sim:.4f}")
# Out:
# Running test SNR sweep...
# CNN sweep @ -10.0 dB …
# CNN sweep @ -5.0 dB …
# CNN sweep @ 0.0 dB …
# CNN sweep @ 5.0 dB …
# CNN sweep @ 10.0 dB …
# CNN sweep @ 15.0 dB …
# CNN sweep @ 20.0 dB …
# CNN sweep @ 25.0 dB …
# CNN sweep @ 30.0 dB …
#   SNR= -10.0  L1_amb=2.8980  SIM_amb=0.0826
#   SNR=  -5.0  L1_amb=2.5125  SIM_amb=0.0679
#   SNR=   0.0  L1_amb=2.3593  SIM_amb=0.0625
#   SNR=   5.0  L1_amb=2.3257  SIM_amb=0.0603
#   SNR=  10.0  L1_amb=2.3352  SIM_amb=0.0603
#   SNR=  15.0  L1_amb=2.3315  SIM_amb=0.0598
#   SNR=  20.0  L1_amb=2.3267  SIM_amb=0.0598
#   SNR=  25.0  L1_amb=2.3290  SIM_amb=0.0599
#   SNR=  30.0  L1_amb=2.3264  SIM_amb=0.0599

# %% [markdown]
# ## Test example @ SNR = 10 dB

# %%
model = diag.load_trained_multires(OUT / f"{TAG}_model.pt", device=DEVICE)
model.eval()

pulse_cfg = filtered_c1_pulse_config(n=64)
dt = float(pulse_cfg.dt)
t_axis = np.linspace(-pulse_cfg.t_total_fs / 2.0, pulse_cfg.t_total_fs / 2.0, pulse_cfg.n)

I_clean, E_true = test_loader.dataset[0]
I_clean_b = I_clean.unsqueeze(0).to(DEVICE)
E_np = E_true.detach().cpu().numpy()
g = torch.Generator()
g.manual_seed(999)
noise = torch.randn(I_clean_b.shape, generator=g, dtype=I_clean_b.dtype)
pwr = I_clean_b.pow(2).mean().clamp_min(1e-12)
sigma = torch.sqrt(pwr / (10.0 ** (10.0 / 10.0)))
I_noisy = I_clean_b + sigma * noise.to(DEVICE)

with torch.no_grad():
    E_pred = extract_pulse_prediction(model(I_noisy.unsqueeze(1))).squeeze(0).cpu().numpy()
e_true = unpack_packed_field(E_np)
e_pred = unpack_packed_field(E_pred)
e_al = best_l1_ambiguity_field(e_pred, e_true)
amp_p, amp_t = np.abs(e_al), np.abs(e_true)
ph_t, ph_p = unwrap_phases_for_overlay(e_al, e_true)
I_n, tau_axis, omega_plot = prepare_frog_trace_for_plot(
    I_noisy.squeeze(0).cpu().numpy(),
    num_points=pulse_cfg.n,
    dt=dt,
)
I_c, _, _ = prepare_frog_trace_for_plot(
    I_clean_b.squeeze(0).cpu().numpy(),
    num_points=pulse_cfg.n,
    dt=dt,
)
energy_ev = omega_plot * 4.135667696 / (2.0 * np.pi)
extent = [tau_axis[0], tau_axis[-1], energy_ev[0], energy_ev[-1]]

fig, axes = plt.subplots(2, 2, figsize=(10, 8))
axes[0, 0].imshow(I_c, aspect="auto", origin="lower", extent=extent, cmap="magma")
axes[0, 0].set_title("clean TRACE")
axes[0, 0].set_xlabel("Delay Ï„ [fs]")
axes[0, 0].set_ylabel("Relative energy [eV]")
axes[0, 1].imshow(I_n, aspect="auto", origin="lower", extent=extent, cmap="magma")
axes[0, 1].set_title("noisy TRACE (SNR=10)")
axes[0, 1].set_xlabel("Delay Ï„ [fs]")
axes[0, 1].set_ylabel("Relative energy [eV]")
axes[1, 0].plot(t_axis, amp_t, label="true")
axes[1, 0].plot(t_axis, amp_p, label="pred")
axes[1, 0].set_title("|E(t)|")
axes[1, 0].set_xlabel("Time [fs]")
axes[1, 0].set_ylabel("|E| [a.u.]")
axes[1, 0].legend()
axes[1, 1].plot(t_axis, ph_t, label="true")
axes[1, 1].plot(t_axis, ph_p, label="pred")
axes[1, 1].set_title("phase")
axes[1, 1].set_xlabel("Time [fs]")
axes[1, 1].set_ylabel("phase [rad]")
axes[1, 1].legend()
plt.suptitle(f"Plain v2 n={N_TRAIN}  LR={LR:g}  test[0] @ 10 dB")
plt.tight_layout()
plt.show()

print("L1_amb:", best_l1_ambiguity(e_pred, e_true))
print("SIM_amb:", best_similarity_error_ambiguity(e_pred, e_true))
# Out:
# L1_amb: 1.7729536294937134
# SIM_amb: 0.027045414381276944

# %% [markdown]
# ## Campaign summary row

# %%
summary = {
    "protocol": PROTOCOL,
    "n_train": N_TRAIN,
    "model": "plain",
    "lambda": 0.0,
    "LR": LR,
    "batch_size": BATCH_SIZE,
    "max_steps": MAX_STEPS,
    "patience_steps": PATIENCE_STEPS,
    "val_snr_values": VAL_SNR_VALUES,
    "best_epoch": meta["best_epoch"],
    "best_step": meta.get("best_step"),
    "best_score_val_amb": meta["best_score"],
    "stopped_epoch": meta["stopped_epoch"],
    "global_step": meta.get("global_step"),
    "wall_time_data_sec": meta.get("wall_time_data_sec"),
    "wall_time_train_sec": meta.get("wall_time_train_sec"),
    "device": meta.get("device"),
    "data": "filtered_c1",
    "tag": TAG,
    "snapshot_val_index": SNAPSHOT_VAL_INDEX,
    "snapshot_snr_db": SNAPSHOT_SNR_DB,
    "snapshot_noise_seed": SNAPSHOT_NOISE_SEED,
}
(OUT / "campaign_summary.json").write_text(
    json.dumps(summary, indent=2), encoding="utf-8"
)
print(json.dumps(summary, indent=2))
print("wrote", OUT / "campaign_summary.json")
# Out:
# {
#   "protocol": "v2",
#   "n_train": 300,
#   "model": "plain",
#   "lambda": 0.0,
#   "LR": 0.001,
#   "batch_size": 64,
#   "max_steps": 6400,
#   "patience_steps": 800,
#   "val_snr_values": [
#     -10.0,
#     0.0,
#     30.0
#   ],
#   "best_epoch": 402,
#   "best_step": 2010,
#   "best_score_val_amb": 2.2696402046084403,
#   "stopped_epoch": 562,
#   "global_step": 2810,
#   "wall_time_data_sec": 9.024100499926135,
#   "wall_time_train_sec": 1090.215432099998,
#   "device": "cuda",
#   "data": "filtered_c1",
#   "tag": "n300_plain_lr1e-3_v2",
#   "snapshot_val_index": 0,
#   "snapshot_snr_db": 10.0,
#   "snapshot_noise_seed": 12345
# }
# wrote d:\Haim\Haim 3rd paper\Ultra-Fast project\src\data efficiency experiment\checkpoints\v2\n300_plain\campaign_summary.json
